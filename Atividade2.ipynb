# %% [markdown]
# ## Atividade 2

# %% [markdown]
# **Alunos:**
#
# *   Alice da Silva de Lima 180112601
# *   João Francisco Gomes Targino 180102991
# *   Vitor Vasconcelos de Oliveira 180114778

# %% [markdown]
# **import de bibliotecas e download de modulos do nltk**

# %%
import pandas as pd
import re
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# **lendo dataframe**

# %%
dataframe = pd.read_csv('/content/twitter-2013train-A.txt', sep='\t', encoding='utf8', names=['id', 'polarity', 'text'])

# %%
dataframe
# Out:
#                       id  polarity  \
# 0     264183816548130816  positive
# 1     263405084770172928  negative
# 2     262163168678248449  negative
# 3     264249301910310912  negative
# 4     262682041215234048   neutral
# ...                  ...       ...
# 9679  103158179306807296  positive
# 9680  103157324096618497  positive
# 9681  100259220338905089   neutral
# 9682  104230318525001729  positive
# 9683  100461938533863424  negative
#
#                                                    text
# 0     Gas by my house hit $3.39!!!! I\u2019m going t...
# 1     Theo Walcott is still shit\u002c watch Rafa an...
# 2     its not that I\u2019m a GSP fan\u002c i just h...
# 3     Iranian general says Israel\u2019s Iron Dome c...
# 4     Tehran\u002c Mon Amour: Obama Tried to Establi...
# ...                                                 ...
# 9679  RT @MNFootNg It's monday and Monday Night Foot...
# 9680  All I know is the road for that Lomardi start ...
# 9681  All Blue and White fam, we r meeting at Golden...
# 9682  @DariusButler28   Have a great game agaist Tam...
# 9683  I'm pisseeedddd that I missed Kid Cudi's show ...
#
# [9684 rows x 3 columns]

# %% [markdown]
# **Criando stop list e substituindo emotes e caracteres especiais ;)**

# %%
stop_list_nltk = nltk.corpus.stopwords.words('english')
stop_list_nltk.append('rt')

# %%
def sub(sentence):
  sentence = re.sub(r':\)', 'happy', sentence)
  sentence = re.sub(r':D', 'happy', sentence)
  sentence = re.sub(r'XD', 'happy', sentence)
  sentence = re.sub(r';\)', 'happy', sentence)
  sentence = re.sub(r'>_<', 'happy', sentence)
  sentence = re.sub(r':\(', 'sad', sentence)
  sentence = re.sub(r';\(', 'sad', sentence)
  sentence = re.sub(r';-;', 'crying', sentence)
  sentence = re.sub(r';_;', 'crying', sentence)
  sentence = re.sub(r'\'-\'', 'annoyed', sentence)
  sentence = re.sub(r':/', 'annoyed', sentence)
  sentence = re.sub(r'\\u2019', '\'', sentence)
  sentence = re.sub(r'u002c', ',', sentence)

  return sentence

# %% [markdown]
# Criando dicionario

# %%
dicio = dict()

# %% [markdown]
# **Definindo função de tokenização que separa palavrs, remove emotes, stop words e lematiza**

# %%
def tokeniza(sentence):
  sentence = sentence.lower()
  tokens = re.split(r'[|\s!$@#,.:;\\\"_?\)\(\]\[/]+',sentence)

  novel_tokens=[]
  for t in tokens:
    if t not in stop_list_nltk and t != '':
      novel_tokens.append(t)
      if t in dicio:
        dicio[t] = dicio[t]+1
      else:
        dicio[t] = 1

  return [lemmatizer.lemmatize(t) for t in novel_tokens]

# %%
sentences = dataframe['text']
sentences[0]
# Out:
# 'Gas by my house hit $3.39!!!! I\\u2019m going to Chapel Hill on Sat. :)'

# %%
final_tweets = []

# %% [markdown]
# **Aplicando tokenização nas sentenças**

# %%
for sentence in sentences:
  sentence = sub(sentence)
  final_tweets.append(tokeniza(sentence))

# %%
final_tweets
# Out:
# [['gas',
#   'house',
#   'hit',
#   '3',
#   '39',
#   "i'm",
#   'going',
#   'chapel',
#   'hill',
#   'sat',
#   'happy'],
#  ['theo',
#   'walcott',
#   'still',
#   'shit',
#   'watch',
#   'rafa',
#   'johnny',
#   'deal',
#   'saturday'],
#  ["i'm", 'gsp', 'fan', 'hate', 'nick', 'diaz', "can't", 'wait', 'february'],
#  ['iranian',
#   'general',
#   'say',
#   "israel's",
#   'iron',
#   'dome',
#   "can't",
#   'deal',
#   'missile',
#   'keep',
#   'talking',
#   'like',
#   'may',
#   'end',
#   'finding'],
#  ['tehran',
#   'mon',
#   'amour',
#   'obama',
#   'tried',
#   'establish',
#   'tie',
#   'mullah',
#   'httpannoyed',
#   'co',
#   'tzzzrrka',
#   'via',
#   'pjmedia',
#   'com',
#   'barack',
#   'obama',
#   '-',
#   'vote',
#   'mitt',
#   'romney'],
#  ['sat', 'whole', 'movie', 'harry', 'ron', 'christmas', 'ohlawd'],
#  ['j',
#   'davlar',
#   '11th',
#   'main',
#   'rival',
#   'team',
#   'poland',
#   'hopefully',
#   'make',
#   'successful',
#   'end',
#   'tough',
#   'week',
#   'training',
#   'tomorrow'],
#  ['talking',
#   "act's",
#   '&&',
#   "sat's",
#   'deciding',
#   'want',
#   'go',
#   'college',
#   'applying',
#   'college',
#   'everything',
#   'college',
#   'stress'],
#  ['happy',
#   'valentine',
#   'day',
#   'trending',
#   '14th',
#   'february',
#   '12th',
#   'june',
#   'smh'],
#  ['may',
#   'superbowl',
#   'dallas',
#   'dallas',
#   "ain't",
#   'winning',
#   'superbowl',
#   'quarterback',
#   'owner',
#   's4nyc',
#   'rasmussenpoll'],
#  ['im',
#   'bringing',
#   'monster',
#   'load',
#   'candy',
#   'tomorrow',
#   'hope',
#   'get',
#   'squiched'],
#  ['apple',
#   'software',
#   'retail',
#   'chief',
#   'overhaul',
#   'san',
#   'francisco',
#   'apple',
#   'inc',
#   'ceo',
#   'tim',
#   'cook',
#   'monday',
#   'replaced',
#   'head',
#   'httpannoyed',
#   'co',
#   'x49zeosg'],
#  ['oluoch',
#   'victor',
#   'otti',
#   'kunjand',
#   'watched',
#   "sridevi's",
#   'comeback',
#   'u',
#   'remember',
#   '90',
#   'sun',
#   'morning',
#   'nta',
#   'happy'],
#  ['one',
#   'best',
#   '8th',
#   'grader',
#   'kory',
#   'excited',
#   'touchdown',
#   'today',
#   'victor',
#   'cruz',
#   'lol',
#   'httpannoyed',
#   'co',
#   'tqorfrxb'],
#  ['livewire',
#   'nadal',
#   'confirmed',
#   'mexican',
#   'open',
#   'february',
#   'rafael',
#   'nadal',
#   'set',
#   'play',
#   'httpannoyed',
#   'co',
#   'zguxpcnc',
#   'livewireathletics'],
#  ['msshelahy',
#   'didnt',
#   'want',
#   'pop',
#   'yep',
#   'chapel',
#   'hill',
#   'next',
#   'wednesday',
#   'come',
#   'shes',
#   'great',
#   'ill',
#   'tell',
#   'asked'],
#  ['alyoup005',
#   'addicted2haley',
#   'hmmmm',
#   'november',
#   'odd',
#   'release',
#   'date',
#   'true',
#   'becomes',
#   'big',
#   'enough',
#   'maybe',
#   'could',
#   'sing',
#   'grammys'],
#  ['iran',
#   'u',
#   'delisting',
#   'mko',
#   'global',
#   'terrorist',
#   'list',
#   'line',
#   'iran',
#   'campaign',
#   'tehran',
#   'oct',
#   '30',
#   'irna',
#   '--',
#   'secretary',
#   'httpannoyed',
#   'co',
#   '9wwvxebf'],
#  ['jackstirling',
#   'serge',
#   'amazing',
#   'like',
#   'he',
#   'actually',
#   'god',
#   'lanky',
#   'sex',
#   'god',
#   'saw',
#   'kasabian',
#   'noel',
#   'together',
#   'august',
#   'amazing'],
#  ['hatersgonnhate',
#   'hamlikehussain',
#   'ramythe3lite',
#   'larry',
#   'bird',
#   'ranked',
#   '4th',
#   'all-time',
#   'including',
#   'lebron',
#   'kobe',
#   'sayin'],
#  ['good',
#   'morning',
#   'becky',
#   'thursday',
#   'going',
#   'fantastic',
#   'swedeng',
#   'dj4jg',
#   'grdina',
#   'paverlayer',
#   'fsbull',
#   'revkahjc',
#   'dickstrash',
#   'borderfox116'],
#  ['expect',
#   'light-moderate',
#   'rain',
#   'e',
#   'visayas',
#   'cebu',
#   'bohol',
#   'samar',
#   '&',
#   'leyte',
#   '30-70%',
#   'chance',
#   'rain',
#   'tonight',
#   'expect',
#   'fair',
#   'weather',
#   'tomorrow',
#   'happy'],
#  ['one',
#   'ticket',
#   'left',
#   '49ers',
#   'game',
#   'tomorrow',
#   'miss',
#   'rematch',
#   'nfc',
#   'championship',
#   'game',
#   'ny',
#   'giant',
#   'hit'],
#  ['afc',
#   'away',
#   'fan',
#   'saturday',
#   'stuff',
#   "'she",
#   'said',
#   "no'",
#   'chant',
#   'bollock',
#   'ball',
#   'turn',
#   'back'],
#  ['saturday',
#   'night',
#   'consisted',
#   'watching',
#   'grey',
#   'puppy',
#   'parent',
#   'throw',
#   'rager',
#   'whaa',
#   'liamneesonisbosstho'],
#  ['hard',
#   'find',
#   'tvguidemagazine',
#   'day',
#   'went',
#   '3',
#   'store',
#   'castle',
#   'cover',
#   'issue',
#   'none',
#   'search',
#   'tomorrow'],
#  ['game',
#   '1',
#   'nlcs',
#   'rematch',
#   'nfc',
#   'championship',
#   'game',
#   'tomorrow',
#   "sf's",
#   'gonna',
#   'cuuuuhraaaaaaaazeeeee'],
#  ['james',
#   'hall',
#   'live',
#   'indianapolis',
#   'dec',
#   '8th',
#   'christ',
#   'church',
#   'apostolic',
#   "'",
#   'tixs',
#   '10',
#   'adv',
#   '15',
#   'door'],
#  ['trevorjavier',
#   'heat',
#   'game',
#   'may',
#   'cost',
#   'alot',
#   'plus',
#   'would',
#   'rather',
#   'see',
#   'austin',
#   'river',
#   'play'],
#  ['never',
#   'start',
#   'working',
#   'dream',
#   'goal',
#   'tomorrow',
#   'tomorrow',
#   'never',
#   'come',
#   'mean',
#   'anything',
#   'u',
#   'act',
#   'getafterit'],
#  ['theffaddict',
#   'vick',
#   'flacco',
#   'needed',
#   'upgrade',
#   'vick',
#   'may',
#   'get',
#   'benched',
#   'jennings',
#   'back',
#   'soon',
#   'thought',
#   'win'],
#  ['lisahochstein',
#   'key',
#   'largo',
#   'fl',
#   'yay',
#   'ur',
#   'neighbor',
#   'lisa',
#   'sip',
#   'n',
#   'hop',
#   'away',
#   'happy',
#   'always',
#   'watching',
#   'rhom',
#   "thur's"],
#  ['look',
#   'like',
#   'andy',
#   'android',
#   'may',
#   'little',
#   'much',
#   'fun',
#   'yesterday',
#   'httpannoyed',
#   'co',
#   '7zdefzec'],
#  ['apgphoto',
#   'oooh',
#   'nice',
#   'ti',
#   'tempting',
#   'go',
#   'lake',
#   'nikon',
#   'hmmmm',
#   'may'],
#  ['black',
#   'friday',
#   'huge',
#   'saving',
#   'aerial',
#   'view',
#   'city',
#   'paris',
#   'la',
#   'vega',
#   'la',
#   'vega',
#   'strip',
#   'la',
#   'vega',
#   'httpannoyed',
#   'co',
#   'dctgesed'],
#  ['yes', 'know', 'indio', 'v', 'cv', 'tomorrow', 'bell', 'game', 'enough'],
#  ['melmurmel',
#   'pbandjenelley',
#   '1',
#   'vl',
#   'delp',
#   'ham',
#   'jenelle',
#   'lie',
#   '1st',
#   'said',
#   'alone',
#   '&the',
#   'hosp',
#   'saying',
#   'weird',
#   "keiffer's"],
#  ['mybeautyisbrown',
#   'lmfao',
#   'big',
#   'as',
#   'get',
#   'nerve',
#   'going',
#   'class',
#   'tomorrow'],
#  ['tantrak',
#   "i'm",
#   'going',
#   'hong',
#   'kong',
#   'time',
#   'mama',
#   'nov',
#   '30',
#   'want',
#   'see',
#   'live'],
#  ['happy', '20th', 'mr', 'president', 'nick', 'j', 'forever', 'chain'],
#  ['dream', 'high', '2', 'suck', 'compared', '1st', 'one'],
#  ['mohamed',
#   'morsi',
#   "egypt's",
#   'muslim',
#   'brotherhood',
#   'president',
#   'instructed',
#   'supreme',
#   'council',
#   'armed',
#   'force',
#   'thursday',
#   'httpannoyed',
#   'co',
#   'nnbeuvst'],
#  ["c'mon",
#   'avila',
#   'got',
#   'tagged',
#   'guy',
#   'look',
#   'like',
#   'kid',
#   'bill',
#   'murray',
#   'researching',
#   'royal',
#   'tenenbaums',
#   'tiger'],
#  ['thehuwdavies',
#   'think',
#   'boro',
#   'beat',
#   'swansea',
#   "i'm",
#   'sure',
#   'december',
#   'january',
#   'implode'],
#  ['first',
#   'grammy',
#   'award',
#   'held',
#   '4',
#   'may',
#   '1959',
#   'domenico',
#   'modugno',
#   'beat',
#   'frank',
#   'sinatra',
#   'peggy',
#   'lee',
#   'record',
#   'year',
#   'volare'],
#  ['happy', 'birthday', 'vow', '3rd', 'anniversary'],
#  ['jennettemchevan',
#   'studied',
#   'day',
#   'tomorrow',
#   "i'm",
#   'going',
#   'friend',
#   'happy',
#   'omg',
#   'jennette',
#   "i'm",
#   'gonna',
#   'look',
#   '<3'],
#  ['good',
#   'morning',
#   'thursday',
#   'life',
#   'fragile',
#   "we're",
#   'guaranteed',
#   'tomorrow',
#   'give',
#   'everything',
#   'got',
#   '-',
#   'tim',
#   'cook',
#   'job'],
#  ['twitition',
#   'mcfly',
#   'come',
#   'back',
#   'argentina',
#   'time',
#   'want',
#   'come',
#   'mar',
#   'del',
#   'plata',
#   'httpannoyed',
#   'co',
#   'dlxy0lcg'],
#  ['astrochologist',
#   'anything',
#   'wondered',
#   'aspect',
#   'btwn',
#   'sun',
#   'moon',
#   'faired',
#   'rising',
#   'also',
#   'venus',
#   'sag',
#   'yea',
#   'lol',
#   'thank',
#   'u',
#   'happy'],
#  ['teacher',
#   'call',
#   'givng',
#   'u',
#   'candy',
#   'even',
#   'good',
#   'stuff',
#   'might',
#   'go',
#   'walmart',
#   'cv',
#   'tomorrow'],
#  ['bronco',
#   'peyton',
#   'manning',
#   'named',
#   'afc',
#   'offensive',
#   'player',
#   'month',
#   '5th',
#   'honor',
#   'second',
#   'tom',
#   "brady's",
#   '6',
#   'tied',
#   'w',
#   'td'],
#  ['toozany',
#   'bringing',
#   'kendrick',
#   'lamar',
#   '6th',
#   'december',
#   'get',
#   'ticket'],
#  ['jackseymour11',
#   'may',
#   'android',
#   'phone',
#   'time',
#   'get',
#   'back',
#   'school',
#   'happy'],
#  ["andre's",
#   'wigan',
#   'warning',
#   '-',
#   'coys',
#   'official',
#   'site',
#   'wigan',
#   'might',
#   'currently',
#   'occupy',
#   '15th',
#   'place',
#   'premier',
#   'league',
#   'httpannoyed',
#   'co',
#   '3mo7wiwd'],
#  ['genesis8907',
#   'tryst',
#   'tonight',
#   'best',
#   'industry',
#   'local',
#   'thursday',
#   'party',
#   'la',
#   'vega'],
#  ['rained',
#   'care',
#   'said',
#   'someday',
#   'soon',
#   'sun',
#   'gonna',
#   'shine',
#   'right',
#   'love',
#   'mine',
#   'valentine'],
#  ['calebmac93',
#   'strokemyego17',
#   'royal',
#   'rumble',
#   'tomorrow',
#   'night',
#   'house',
#   'assemble',
#   'crew',
#   'gettin',
#   'real',
#   'time',
#   'haahaha'],
#  ['juice005',
#   'strange',
#   'enough',
#   "i'm",
#   'going',
#   'see',
#   'noel',
#   'gallagher',
#   'concert',
#   'tomorrow',
#   'night',
#   'alldayb1tch'],
#  ['professor',
#   'pass',
#   'candy',
#   'say',
#   'small',
#   'amount',
#   'may',
#   'valentine',
#   'day',
#   'know'],
#  ['going',
#   'act',
#   'new',
#   'york',
#   'subway',
#   'better',
#   'clutch',
#   'like',
#   'eli',
#   'manning',
#   '4th',
#   'quarter'],
#  ['homegrown',
#   'talent',
#   'missing',
#   'signing',
#   'day',
#   'throughout',
#   'day',
#   'wednesday',
#   'video',
#   'scoreboard',
#   'httpannoyed',
#   'co',
#   '6dz2hqkd',
#   'raleigh'],
#  ['taylor',
#   'swift',
#   'coming',
#   'ed',
#   'sheeran',
#   'june',
#   '29th',
#   'perf',
#   'news',
#   "i've",
#   'heard',
#   'night'],
#  ['great',
#   'noel',
#   'gallagher',
#   'hit',
#   'stage',
#   'st',
#   'paul',
#   'plenty',
#   'room',
#   "we're",
#   '4th',
#   'row',
#   'center',
#   'plenty',
#   'room',
#   'pretty',
#   'fired'],
#  ["i'd", 'love', 'go', 'pint', 'jim', 'white', 'ssn', 'think', 'may', 'bit'],
#  ['lala',
#   'cox',
#   'going',
#   'plenty',
#   'ups',
#   '&',
#   'down',
#   'boro',
#   'cardiff',
#   'leicester',
#   'etc',
#   'may',
#   'hope',
#   'still',
#   'shout',
#   'promo'],
#  ['joeeewilliams',
#   'suck',
#   'amazon',
#   'might',
#   'left',
#   'hate',
#   '11am',
#   'tuesday',
#   'though'],
#  ['happy',
#   'sunday',
#   'last',
#   'sadat',
#   'back',
#   'work',
#   'enjoy',
#   'tweeps',
#   'yard',
#   'work',
#   'couple',
#   'hour',
#   'fun'],
#  ['playing',
#   'brown',
#   'hc',
#   'k',
#   'fri',
#   'madden13',
#   'xfacalac',
#   'lost',
#   'raven',
#   '21-28',
#   'all-madden',
#   'connectedcareers'],
#  ['cfc',
#   'juanmata10',
#   'best',
#   'premier',
#   'league',
#   'overall',
#   'ea',
#   'sport',
#   'player',
#   'performance',
#   'index',
#   'score',
#   '217',
#   '1st',
#   'place',
#   'matamagic'],
#  ['rosanne',
#   '89',
#   'nooooooooo',
#   'rosanne',
#   "they've",
#   'restocked',
#   'going',
#   'overseas',
#   'sunday',
#   'mean',
#   "can't",
#   'afford',
#   "'"],
#  ['pain',
#   'far',
#   'deeper',
#   'billy',
#   'cundiff',
#   'missed',
#   'field',
#   'goal',
#   'gotta',
#   'wake',
#   'forget',
#   'tomorrow',
#   'oriole',
#   'stayhungry'],
#  ['grandvincenzo',
#   'november',
#   '16',
#   'ready',
#   'head',
#   'movie',
#   'breaking',
#   'dawn',
#   'part',
#   '2'],
#  ['seeing',
#   'iam',
#   "faithreid's",
#   'tweet',
#   'watching',
#   'vow',
#   'think',
#   'may',
#   'need',
#   'watch'],
#  ['tomorrow',
#   'shall',
#   'consist',
#   'watching',
#   'ferrell',
#   'film',
#   'fave',
#   'people',
#   'chinese',
#   'food',
#   'sweet'],
#  ['yeah',
#   'know',
#   'sitting',
#   'around',
#   'listening',
#   'avril',
#   'lavigne',
#   'typical',
#   'friday',
#   'night'],
#  ['cardschatter',
#   'azcardinalsftw',
#   'closest',
#   'source',
#   'btwn',
#   'fan',
#   '&',
#   'team',
#   'btw',
#   'heard',
#   'card',
#   'may',
#   'sign',
#   'billy',
#   'cundiff',
#   'truth',
#   'snarklife'],
#  ['jbmclendon',
#   'station',
#   'air',
#   'new',
#   'episode',
#   'cougar',
#   'town',
#   'january',
#   'tbsveryfunny',
#   'good',
#   'u',
#   'jordan',
#   'pennycan'],
#  ['alex',
#   'poythress',
#   '11',
#   'point',
#   '7',
#   'rebound',
#   'debut',
#   'kentucky',
#   'exhibition',
#   'game',
#   'thursday',
#   'played',
#   '28',
#   'minute'],
#  ['think',
#   'may',
#   'heart',
#   'attack',
#   'jason',
#   "wu's",
#   'new',
#   'collection',
#   'charlotte',
#   'rampling',
#   'night',
#   'httpannoyed',
#   'co',
#   '2krw4ktn'],
#  ['get',
#   'equipment',
#   'working',
#   'correctly',
#   'live',
#   'show',
#   'friday',
#   '6',
#   'pm',
#   'cst',
#   'contactee',
#   'ray',
#   'httpannoyed',
#   'co',
#   '9lvkwcyj'],
#  ['amazing',
#   'concert',
#   'tonight',
#   'jim',
#   'white',
#   'tcu',
#   'jazz',
#   'ensemble',
#   'faculty',
#   'jazz',
#   'combo',
#   'miss',
#   'tomorrow',
#   'night',
#   'httpannoyed',
#   'co',
#   'i9asnset'],
#  ['national',
#   '9th',
#   'inning',
#   '4th',
#   'quarter',
#   'redskin',
#   'feel',
#   'coulda',
#   'swore',
#   'saw',
#   'cundiff',
#   'shank',
#   'one',
#   'mound'],
#  ['would',
#   'still',
#   'wear',
#   'short',
#   'cold',
#   'love',
#   'britain',
#   "see's",
#   'bit',
#   'sun',
#   "they're",
#   'like',
#   "'oooh",
#   "let's",
#   'strip',
#   "'"],
#  ['ppppolls',
#   'mentioned',
#   'monday',
#   'would',
#   'releasing',
#   'colorado',
#   'nevada',
#   'number',
#   'wednesday',
#   'poll',
#   'abandoned'],
#  ['capello',
#   'say',
#   'time',
#   'russia',
#   'win',
#   'big',
#   'match',
#   'russia',
#   'manager',
#   'fabio',
#   'capello',
#   'thursday',
#   'said',
#   'intended',
#   'httpannoyed',
#   'co',
#   'efc5cfng'],
#  ['jackal',
#   'goal',
#   'jimmy',
#   'martin',
#   'sneak',
#   'rebound',
#   'past',
#   'killeen',
#   'give',
#   'elmira',
#   '2-1',
#   'lead',
#   'bushee',
#   '&',
#   'bellamy',
#   'assist',
#   '1',
#   '09',
#   'left',
#   '2nd',
#   'period'],
#  ['kick-off',
#   'weekend',
#   'service',
#   'ev',
#   "'s",
#   'get',
#   'bus',
#   'trip',
#   'boy',
#   '&',
#   'girl',
#   'club',
#   'friday',
#   '3-6',
#   'hope',
#   'see',
#   'happy'],
#  ['nater0driguez',
#   'lmfao',
#   'alright',
#   'u',
#   'got',
#   'good',
#   'job',
#   'parker',
#   'spur',
#   'see',
#   "y'all",
#   'jan',
#   '9th',
#   'get',
#   'extra',
#   'ticket',
#   'game',
#   'ur',
#   'goin'],
#  ['desperation',
#   'day',
#   'february',
#   '13th',
#   'well',
#   'known',
#   'day',
#   'men',
#   'life'],
#  ['sunnyclifford',
#   'similar',
#   'circumstance',
#   'australia',
#   'jan',
#   '25',
#   'australia',
#   'day',
#   '&',
#   'many',
#   'first',
#   'people',
#   'call',
#   'invasion',
#   'day'],
#  ['paul-and5homos',
#   'harry',
#   'louis',
#   'fri-',
#   'eleanor',
#   'inspira-',
#   'harry',
#   'manwho-',
#   'louis',
#   'httpannoyed',
#   'co',
#   'jxxtnlu6'],
#  ['web',
#   'apple',
#   'software',
#   'retail',
#   'chief',
#   'overhaul',
#   'san',
#   'francisco',
#   'reuters',
#   '-',
#   'apple',
#   'inc',
#   'ceo',
#   'tim',
#   'cook',
#   'monday',
#   'replaced',
#   'head'],
#  ['two',
#   'may',
#   'fight',
#   'like',
#   'cat',
#   'dog',
#   'completely',
#   'head',
#   'heel',
#   'two',
#   'like',
#   'allie',
#   'noah',
#   'notebook'],
#  ['paperchasinal',
#   'damn',
#   'next',
#   'saturday',
#   'tho',
#   'nigga',
#   'trynna',
#   'get',
#   'shit',
#   'early'],
#  ['4th', 'one', 'harry', 'style', '<33333'],
#  ['guy',
#   'much',
#   'like',
#   'bruno',
#   'mar',
#   'crazy',
#   'may',
#   'long',
#   'lost',
#   'twin'],
#  ['blog',
#   'post',
#   "mtv's",
#   'teen',
#   'mom',
#   '2',
#   'return',
#   'intense',
#   'third',
#   'season',
#   'chelsea',
#   'jenelle',
#   'kailyn',
#   'leah',
#   'monday',
#   'httpannoyed',
#   'co',
#   'mgmhsfvu'],
#  ['business',
#   "leader's",
#   'award',
#   'ceremony',
#   'held',
#   'wef',
#   'annual',
#   'meeting',
#   'davos',
#   '25',
#   'january',
#   '2013',
#   'httpannoyed',
#   'co',
#   'yi4r8ufm'],
#  ['elifyk1',
#   'hi',
#   'elif',
#   'greeting',
#   'usa',
#   'midwest',
#   'school',
#   'going',
#   'happy',
#   'turkish',
#   'republic',
#   'day',
#   "can't",
#   'wait',
#   'nov',
#   '8',
#   'newglee',
#   'yes'],
#  ['hoping', 'look', 'fit', 'tomorrow', 'jeremy', 'kyle', 'show', 'itvfashion'],
#  ['jordon', 'atkins', 'joe', 'gone', 'chill', 'saturday', 'come', 'tho'],
#  ['obma',
#   'fails',
#   '2unite',
#   'u',
#   'divide',
#   'u',
#   'sex',
#   'color',
#   'party',
#   'age',
#   'wealth',
#   "nevada's",
#   '1st',
#   'latino',
#   'governor',
#   'vote',
#   'early',
#   'romney',
#   'predicts',
#   'gop',
#   'win'],
#  ['grammys',
#   'concert',
#   'pay',
#   'moving',
#   'tribute',
#   'whitney',
#   'houston',
#   'whitney',
#   'houston',
#   'given',
#   'final',
#   'sendoff',
#   'grammys',
#   'thursday',
#   'halle'],
#  ['calling',
#   'voter',
#   "i'm",
#   'calling',
#   'nevada',
#   'florida',
#   'ohio',
#   'tuesday',
#   'night',
#   'night',
#   'u',
#   'guy',
#   'repeat',
#   'shine',
#   'president',
#   'let',
#   'go'],
#  ['tallied',
#   'vote',
#   'announcing',
#   'winner',
#   'calling',
#   'community',
#   'tune',
#   'httpannoyed',
#   'co',
#   'xmaxmlcq',
#   'nov',
#   '1st',
#   '11am',
#   'cst'],
#  ['radio',
#   '1',
#   'rock',
#   'next',
#   '-',
#   'week',
#   'starting',
#   'live',
#   'lounge',
#   "fearnecotton's",
#   'show',
#   'bullet',
#   'valentine',
#   'monday'],
#  ['drew',
#   'peterson',
#   'untouchable',
#   'check',
#   'movie',
#   'photo',
#   'watch',
#   'sun',
#   '7',
#   '6c',
#   'httpannoyed',
#   'co',
#   'lt9wukod'],
#  ['hotspurrelated',
#   'im',
#   '19',
#   'year',
#   'old',
#   'still',
#   'loan',
#   '3rd',
#   'time',
#   'coventry',
#   '79',
#   'overall',
#   'hopefully',
#   'return',
#   'bale',
#   'still',
#   'ther'],
#  ['halloween',
#   'may',
#   'second',
#   'worst',
#   'holiday',
#   'right',
#   "valentine's",
#   'day'],
#  ['pumped',
#   'open',
#   'season',
#   'tomorrow',
#   'night',
#   'georgetown',
#   "women's",
#   'preview',
#   'httpannoyed',
#   'co',
#   '1k3pak3c',
#   "men's",
#   'preview',
#   'httpannoyed',
#   'co',
#   'n5ofat9v'],
#  ['found', 'piece', 'candy', 'may', 'injected', 'something'],
#  ['apple',
#   'shakeup',
#   'mobile',
#   'software',
#   'bos',
#   'eased',
#   'apple',
#   'inc',
#   'ceo',
#   'tim',
#   'cook',
#   'monday',
#   'pushed',
#   'powerful',
#   'head',
#   'company&',
#   '039',
#   'mo'],
#  ['somehow',
#   'managed',
#   'lose',
#   'princess',
#   'leia',
#   'bra',
#   'saturday',
#   "i'm",
#   'going',
#   'noel',
#   'gallagher',
#   'glock',
#   'phish',
#   'ie',
#   'jorts&tank',
#   'custymcnoob'],
#  ['docbungle',
#   'may',
#   'relent',
#   'get',
#   'one',
#   'hope',
#   'come',
#   'hopefully',
#   'decent',
#   'apps',
#   'get',
#   'ported',
#   'android'],
#  ['android',
#   '4',
#   '2',
#   'camera',
#   'app',
#   'photo',
#   'sphere',
#   'available',
#   'galaxy',
#   'nexus',
#   'introduced',
#   'monday',
#   'android',
#   '4',
#   '2',
#   'bring',
#   'httpannoyed',
#   'co',
#   'yl8qqp0r'],
#  ['saeed',
#   'nowplaying',
#   'bep',
#   'ricky',
#   'martin',
#   'kt',
#   'tunstall',
#   'great',
#   'song',
#   'get',
#   'sunday',
#   'hate',
#   'rain',
#   'httpannoyed',
#   'co',
#   'c9pmolgw'],
#  ['juliecrawley25',
#   'gininjadesign',
#   'donna',
#   'butlin',
#   'nope',
#   'camden',
#   'eating',
#   'greek',
#   'food',
#   'pumpkin',
#   'another',
#   'wednesday'],
#  ['ready',
#   'shop',
#   'new',
#   'collection',
#   'h&m',
#   'tomorrow',
#   'grey',
#   'concept',
#   'h&m',
#   'httpannoyed',
#   'co',
#   'jqe4rjyb',
#   'fashion',
#   'shopping',
#   'highstreet'],
#  ['faq',
#   "'skeuomorphic",
#   "design'",
#   'executive',
#   'shakeup',
#   'apple',
#   'san',
#   'francisco',
#   'ca',
#   '-',
#   'march',
#   '07',
#   'apple',
#   'ceo',
#   'httpannoyed',
#   'co',
#   'ycvopl98'],
#  ['fact',
#   'day',
#   'halloween',
#   'night',
#   'papa',
#   "john's",
#   'second',
#   'busiest',
#   'night',
#   'year',
#   'behind',
#   'super',
#   'bowl',
#   'sunday'],
#  ['nicoleandrews',
#   'one',
#   'hold',
#   'candle',
#   'queen',
#   'coco',
#   'still',
#   'show',
#   'august',
#   'wedding',
#   'go'],
#  ['omg', 'ricky', 'martin', 'may', 'gay', 'one', 'fine', 'as', 'gay', 'man'],
#  ['lenakoncha',
#   'clipper',
#   'playing',
#   'cavalier',
#   'monday',
#   'night',
#   'honor',
#   'israel',
#   'happy',
#   'wish',
#   'la',
#   'still'],
#  ['bright', 'side', "tomorrow's", 'chocolate', 'day', 'getexcited'],
#  ['um',
#   'learned',
#   'sunday',
#   'national',
#   'chocolate',
#   'day',
#   "i'm",
#   'totally',
#   'taking',
#   'advantage'],
#  ["90's",
#   'lady',
#   'see',
#   '15th',
#   'dec',
#   '-',
#   'axl',
#   'rose',
#   'selzky',
#   'trisiska',
#   'putri',
#   'inadio',
#   'teaser',
#   'biar',
#   'gak',
#   'kecewa',
#   'httpannoyed',
#   'co',
#   'hqznzmzx'],
#  ['noel',
#   'gallagher',
#   'musician',
#   'fucking',
#   'idiot',
#   '-',
#   'yeah',
#   'brian',
#   'may',
#   '-',
#   "he's",
#   'idiot',
#   'idiot',
#   'happens',
#   'professor'],
#  ['vow',
#   'likely',
#   'return',
#   'midsummer',
#   'break',
#   'prix',
#   'de',
#   'royallieu',
#   'longchamp',
#   'saturday',
#   'httpannoyed',
#   'co',
#   'fmocg7yk'],
#  ['hope',
#   'forhippies',
#   'hell',
#   'yea',
#   'lmfaoo',
#   '&',
#   'see',
#   'tomorrow',
#   'asia',
#   'baby'],
#  ['real',
#   'liam',
#   'payne',
#   'wanted',
#   'know',
#   'argentina',
#   'going',
#   'make',
#   'directioner',
#   'fest',
#   '10',
#   'november',
#   'te',
#   'amo',
#   'te',
#   'amo',
#   'te',
#   'amo'],
#  ['november',
#   'already',
#   'christmas',
#   'soon',
#   'new',
#   'year',
#   "valentine's",
#   'day',
#   'graduation'],
#  ['nowplaying',
#   'michael',
#   'jackson',
#   '-',
#   'life',
#   'live',
#   'wembley',
#   'july',
#   '16',
#   'httpannoyed',
#   'co',
#   'vxryuadn',
#   'l',
#   'v',
#   'e',
#   'mjtunes'],
#  ['nigga',
#   'lakers',
#   'dick',
#   'still',
#   'gon',
#   'finish',
#   'damn',
#   'near',
#   'first',
#   'seed',
#   'yo',
#   'team',
#   'struggling',
#   '8th',
#   'spot'],
#  ['reditlhabi',
#   'stevenb7777',
#   'october',
#   'people',
#   'principle',
#   '&',
#   'argue',
#   'passionately',
#   '&',
#   'act',
#   'ghandi',
#   'sadat',
#   'adt'],
#  ['amberrblack',
#   'amber',
#   'fantastic',
#   'news',
#   'reunite',
#   'barbara',
#   'jenelle',
#   'november',
#   '21st',
#   'teen',
#   'mom',
#   '2',
#   'premiere'],
#  ['need',
#   'another',
#   'viv',
#   'necklace',
#   'may',
#   'buy',
#   'one',
#   'valentine',
#   'day',
#   'nojoke'],
#  ["i'm",
#   'bathroom',
#   'bumping',
#   'nigga',
#   'paris',
#   'crunk',
#   'as',
#   'hell',
#   'like',
#   '1st',
#   'time',
#   'hearing',
#   'song',
#   'never',
#   'get',
#   'old',
#   'lol'],
#  ['got',
#   'ticket',
#   'see',
#   'muse',
#   'florida',
#   'combined',
#   'grammys',
#   'two',
#   'week',
#   'prior',
#   'equal',
#   'really',
#   'busy',
#   'february',
#   'ruby'],
#  ['welcome', 'nick', 'j', 'nickjonas', 'manila', 'excited', 'show', 'friday'],
#  ['battle', '17th', 'banner', 'royal', 'rumble', 'basketball', 'edition'],
#  ['matter',
#   'anyone',
#   'say',
#   'ray',
#   'lewis',
#   'may',
#   'best',
#   'defensive',
#   'player',
#   'ever',
#   'play',
#   'game',
#   'he',
#   'got',
#   'heart',
#   'he',
#   'got',
#   'anger'],
#  ['4th',
#   'album',
#   'red',
#   '20millionswifties',
#   '6',
#   'grammy',
#   'award',
#   '10',
#   'amas',
#   '13',
#   'bmi',
#   'award',
#   'reigning',
#   'entertainer',
#   'year',
#   'acm',
#   '6yearstaylorswift'],
#  ['smooch',
#   'fido',
#   'yea',
#   'nay',
#   '-',
#   'july',
#   '6th',
#   'international',
#   'kissing',
#   'day',
#   'human',
#   'sort',
#   'later',
#   'month',
#   'ca',
#   'httpannoyed',
#   'co',
#   'ctbrbift'],
#  ['midnight',
#   'east',
#   'coast',
#   'mean',
#   'nickjonas',
#   'birthday',
#   'happy',
#   '20th',
#   'birthday',
#   'nick',
#   'j',
#   '<333'],
#  ['apple',
#   'ceo',
#   'apologizes',
#   'error-ridden',
#   'new',
#   'map',
#   'app',
#   'apple',
#   'ceo',
#   'tim',
#   'cook',
#   'apologized',
#   'friday',
#   "company's",
#   'error-ridden',
#   'new',
#   'mobile',
#   'map'],
#  ['monta',
#   'elli',
#   'elli',
#   'provided',
#   'five',
#   'point',
#   '2-of-13',
#   'shooting',
#   'thursday',
#   'httpannoyed',
#   'co',
#   'aerfhhuk',
#   'nba',
#   'playersnews'],
#  ['teach',
#   'basketball',
#   'school',
#   "we're",
#   'gonna',
#   'spend',
#   '1st',
#   'day',
#   'watching',
#   'larry',
#   'bird',
#   'video',
#   '&',
#   'rest',
#   'take',
#   'care'],
#  ['at&t',
#   'offer',
#   'free',
#   'cloud',
#   'storage',
#   'io',
#   'android',
#   'at&t',
#   'thursday',
#   'announced',
#   'new',
#   'service',
#   'call',
#   'at&t',
#   'locker',
#   'th',
#   'httpannoyed',
#   'co',
#   '7yovkmmx'],
#  ['nbcofchicago',
#   '12th',
#   'anniversary',
#   'celebration',
#   'still',
#   'time',
#   'make',
#   '-',
#   '6620',
#   'king',
#   'dr'],
#  ['karimandsugar',
#   'told',
#   'shane',
#   'would',
#   'get',
#   '5th-star',
#   'rival',
#   'signing',
#   'day',
#   'taylor',
#   'mcneill7'],
#  ['mysticvalley',
#   'mitch',
#   'free',
#   'sunday',
#   'bale',
#   'leaf',
#   'hour',
#   'big',
#   'deal',
#   'animal'],
#  ['stevefekete',
#   'altberry',
#   'ferlazz',
#   'jimmymcgorman',
#   'rodneyondrums',
#   'heart',
#   'explode',
#   'need',
#   'new',
#   "avril's",
#   '4th',
#   'album'],
#  ['love',
#   'skipped',
#   'every',
#   'category',
#   "nta's",
#   'besides',
#   'soap',
#   'give',
#   'half',
#   'fuck',
#   'everything',
#   'else',
#   'went',
#   'air',
#   'tomorrow'],
#  ['starky88',
#   'nfl',
#   'uk',
#   'sat',
#   'ray',
#   'lewis',
#   'home',
#   'jersey',
#   'lot',
#   'either'],
#  ['new',
#   'york',
#   'giant',
#   'game-by-game',
#   'prediction',
#   '2nd',
#   'half',
#   'season',
#   'httpannoyed',
#   'co',
#   'yk9vtjcs'],
#  ["c'mon", "c'mon", 'sound', 'like', "queen's", 'rock', 'somehow'],
#  ['mashed',
#   'nigga',
#   'paris',
#   'club',
#   'paris',
#   'cliche',
#   'may',
#   'sound',
#   'weouthere'],
#  ['pick',
#   'chelsea',
#   'team',
#   'play',
#   'swansea',
#   '-',
#   "chelsea's",
#   'focus',
#   'turn',
#   'back',
#   'premier',
#   'league',
#   'saturday',
#   'make',
#   'httpannoyed',
#   'co',
#   '6az8jiiz'],
#  ['markukleaf',
#   'look',
#   'seems',
#   'nash',
#   'davos',
#   'done',
#   'deal',
#   'along',
#   'joe',
#   'thornton',
#   'may',
#   'pay',
#   'visit'],
#  ['mom',
#   'texted',
#   'reminding',
#   'grammys',
#   'birthday',
#   'tomorrow',
#   'could',
#   'ever',
#   'forget',
#   'biggestdayoftheyear'],
#  ['ariaclemente',
#   'wow',
#   'also',
#   'percy',
#   'jackson',
#   'fan',
#   '-',
#   '4th',
#   'book',
#   'hero',
#   'olympus',
#   'entitled',
#   'house',
#   'hades',
#   'camphalfblood'],
#  ['esperance',
#   'without',
#   'star',
#   'player',
#   'youssef',
#   'msakni',
#   'first',
#   'leg',
#   'champion',
#   'league',
#   'final',
#   'al',
#   'ahly',
#   'saturday',
#   'africa'],
#  ['chrischris',
#   'sun',
#   'paolo',
#   'di',
#   'canio',
#   'say',
#   'beating',
#   'aston',
#   'villa',
#   'tonight',
#   'would',
#   'like',
#   'sex',
#   'madonna',
#   'legend'],
#  ['obviously',
#   'fan',
#   'dream',
#   'high',
#   '2',
#   'even',
#   'watched',
#   'well',
#   'watched',
#   '1st',
#   'ep',
#   "that's",
#   'heard',
#   'song',
#   '^^'],
#  ['black',
#   'history',
#   'fact',
#   'marsalis',
#   '1st',
#   'artist',
#   'win',
#   'classical',
#   'jazz',
#   'grammy',
#   'award',
#   'one',
#   'year',
#   'repeat',
#   'next',
#   'yr'],
#  ['watching',
#   'david',
#   'letterman',
#   'audience',
#   'playing',
#   'like',
#   'still',
#   '2nd',
#   'brilliant',
#   'thing',
#   "i've",
#   'seen',
#   'tonight'],
#  ['gov',
#   'mitch',
#   'daniel',
#   'announce',
#   'indiana',
#   'supreme',
#   'court',
#   'pick',
#   '10',
#   '3rd',
#   'time',
#   'charm',
#   'female',
#   'member',
#   'panel'],
#  ['goodnight',
#   'everyone',
#   'talk',
#   'tomorrow',
#   'happy',
#   'shall',
#   'leave',
#   'harry',
#   'style',
#   '-a',
#   'httpannoyed',
#   'co',
#   'fc1zkow7'],
#  ['common',
#   'night',
#   'order',
#   'pizza',
#   'nye',
#   'jan',
#   '1',
#   'day',
#   'thanksgiving',
#   'super',
#   'bowl',
#   'sunday',
#   'halloween',
#   'httpannoyed',
#   'co',
#   '3j3qil3j'],
#  ['grey',
#   'yellow',
#   'gold',
#   'wedding',
#   'puzzle',
#   'first',
#   'piece',
#   'unique',
#   'two-tone',
#   'dress',
#   'shopbop',
#   'httpannoyed',
#   'co',
#   '1ryso3zz'],
#  ['listening',
#   'kendrick',
#   'lamar',
#   'even',
#   'want',
#   'get',
#   'hair',
#   'cut',
#   'tomorrow'],
#  ['harakah',
#   'iran',
#   'army',
#   'monitoring',
#   'ship',
#   'gulf',
#   'tehran',
#   'oct',
#   '28',
#   'senior',
#   'commander',
#   'islamic',
#   'revolution',
#   'gu',
#   'httpannoyed',
#   'co',
#   'hbdrqp3p'],
#  ['ht',
#   'norwich',
#   '0-0',
#   'spur',
#   "we've",
#   'edged',
#   '1st',
#   'half',
#   'without',
#   'creating',
#   'clear',
#   'cut',
#   'chance',
#   "bale's",
#   'couple',
#   'decent',
#   'long',
#   'range',
#   'effort'],
#  ['guy',
#   'marijuana',
#   'law',
#   'colorado',
#   'oregon',
#   'washington',
#   'pas',
#   'tuesday',
#   'highhopes'],
#  ["breezin'",
#   'best',
#   'pop',
#   'instrumental',
#   'performance',
#   '19th',
#   'grammy',
#   'award'],
#  ['pacino',
#   'going',
#   'play',
#   'joe',
#   'paterno',
#   '2nd',
#   'time',
#   'starred',
#   'film',
#   'line',
#   "'say",
#   'hello',
#   'little',
#   'friend',
#   '-',
#   'snl'],
#  ['wearing',
#   'make',
#   'dublin',
#   'tomorrow',
#   "i'm",
#   'getting',
#   'ready',
#   'party',
#   'help'],
#  ['snow',
#   'may',
#   'fall',
#   'part',
#   'cny',
#   'next',
#   'day',
#   'find',
#   'best',
#   'chance',
#   '6',
#   '42',
#   'tv',
#   '&',
#   'online',
#   'httpannoyed',
#   'co',
#   'f0kb0gqd'],
#  ['seem',
#   'like',
#   'austin',
#   'river',
#   'tryin',
#   'get',
#   'bucket',
#   'feel',
#   'em',
#   'tho',
#   '1st',
#   'game',
#   'league',
#   'trying',
#   'hard'],
#  ['cofield', 'draw', 'leadoff', 'walk', 'top', '4th', 'zaharion', 'plate'],
#  ['biebergomeztour',
#   'aww',
#   'celebrity',
#   'day',
#   'thursday',
#   'also',
#   'going',
#   'jennifer',
#   'hudson',
#   'though',
#   'happy'],
#  ['mehdusta',
#   'miss',
#   'better',
#   'get',
#   'juge',
#   'kiss',
#   'hug',
#   'tomorrow',
#   'night',
#   "joe's",
#   'happy'],
#  ['took',
#   'ten',
#   'click',
#   'figure',
#   'early',
#   'vote',
#   'colorado',
#   'site',
#   'say',
#   'need',
#   'bring',
#   "c'mon",
#   'colosecofstate'],
#  ['sat', 'watch', 'michael', 'jackson', 'dvd', 'xx'],
#  ['set',
#   'axis',
#   'nigerian',
#   'economy',
#   'airing',
#   'every',
#   'tuesday',
#   '8',
#   '30pm',
#   'nta',
#   'international',
#   'dstv',
#   'httpannoyed',
#   'co',
#   'qfvon8uj'],
#  ['text',
#   'dad',
#   'like',
#   'charles',
#   'dickens',
#   '1',
#   'obvs',
#   'looking',
#   'amazon',
#   'wish',
#   'list',
#   'late',
#   'sunday',
#   '2',
#   'th',
#   'surprise'],
#  ['upset',
#   'alert',
#   'acc',
#   "men's",
#   'soccer',
#   '1',
#   'maryland',
#   '4-2',
#   'wake',
#   'forest',
#   'late',
#   '2nd',
#   'man',
#   'earlier',
#   'red',
#   'card'],
#  ['really',
#   'bored',
#   'host',
#   'super',
#   'sunday',
#   'nothing',
#   'talk',
#   'rave',
#   'man',
#   'utd',
#   'biasprick'],
#  ['may',
#   'missed',
#   'seeing',
#   'noel',
#   'fielding',
#   'rich',
#   'fulcher',
#   'today',
#   'see',
#   'tom',
#   'tilley',
#   'samsimmons'],
#  ['thankfully',
#   "he's",
#   'germany',
#   'come',
#   'home',
#   'january',
#   'still',
#   'dangerous',
#   'though'],
#  ['looper',
#   'amazing',
#   'theatre',
#   'see',
#   'simon',
#   "callow's",
#   "'the",
#   'mystery',
#   'charles',
#   "dickens'",
#   'loving',
#   'wednesday',
#   'work',
#   '-'],
#  ['october',
#   'baby',
#   'happy',
#   "valentine's",
#   'day',
#   'folk',
#   'annual',
#   'memory'],
#  ['negro',
#   'nigglettes',
#   'would',
#   'like',
#   'attend',
#   'ap',
#   'rocky',
#   'concert',
#   'november',
#   '17th',
#   'starland',
#   'lemme',
#   'know',
#   'ticket',
#   '25'],
#  ['wish',
#   'maddie',
#   'luck',
#   'next',
#   'saturday',
#   'solo',
#   'audition',
#   "britain's",
#   'got',
#   'talent',
#   'happy',
#   '~',
#   'ellie',
#   'xxxxx'],
#  ['nfl',
#   'victor',
#   'cruz',
#   'went',
#   'public',
#   'month',
#   'desire',
#   'new',
#   'contract',
#   'tuesday',
#   'giant',
#   'rec',
#   'httpannoyed',
#   'co',
#   'yzl60chd',
#   'football'],
#  ['%',
#   'joe',
#   'pa',
#   'mask',
#   'penn',
#   'state',
#   'sat',
#   'psu',
#   'allow',
#   'stadium',
#   'bad',
#   'wear',
#   'espngreeny'],
#  ['meganwitmer',
#   "that's",
#   'crazy',
#   "i'm",
#   'jealous',
#   'u',
#   'going',
#   'joe',
#   "pa's",
#   'grave',
#   'sad',
#   'saturday',
#   'walked',
#   'past',
#   'statue',
#   'besad'],
#  ['mizzou',
#   'commemorates',
#   'win',
#   'kentucky',
#   't-shirt',
#   'really',
#   'dr',
#   'saturday',
#   '-',
#   'yahoo',
#   'sport',
#   'httpannoyed',
#   'co',
#   '2u46bvq6',
#   'fb'],
#  ['rock',
#   'face',
#   'wwe',
#   'title',
#   'royal',
#   'rumble',
#   'voted',
#   'rockpunk',
#   'would',
#   '1st',
#   'see'],
#  ['fruitpunchtoday',
#   'lol',
#   'year',
#   'may',
#   'chance',
#   'superbowl',
#   'must',
#   'wait',
#   'nick',
#   'foley'],
#  ['vikingdane1',
#   'thinking',
#   'bolt',
#   'action',
#   '30-06',
#   'may',
#   'card',
#   "valentine's",
#   'day',
#   'something'],
#  ['happy', "valentine's", 'day', 'maziing', 'everyday', '14th'],
#  ['finish',
#   'reading',
#   'paterno',
#   'tomorrow',
#   'watch',
#   'football',
#   'sunday',
#   'monday',
#   'prepare',
#   'nba2k13',
#   'release',
#   '120pagesleft'],
#  ['xbecx92', 'may', 'indian', 'time', 'tonite', 'becky', '-', 'xx'],
#  ['watched',
#   'campaign',
#   'ferrell',
#   'zack',
#   'galafianakis',
#   'good',
#   'fun',
#   'wednesday',
#   'hilarious'],
#  ['sumeetkulkarni', 'season', 'end', 'superbowl', 'first', 'week', 'february'],
#  ['hilciajsu',
#   'review',
#   'reminded',
#   'still',
#   'need',
#   '2',
#   'read',
#   '1st',
#   'percy',
#   'jackson',
#   'book',
#   'hero',
#   'olympus',
#   'offshoot',
#   'series'],
#  ['crazy',
#   'meeting',
#   'old',
#   'nba',
#   'player',
#   'picked',
#   '3rd',
#   'larry',
#   'bird'],
#  ['sunday', 'new', 'york', 'giant', 'going', 'steelers'],
#  ['introduction',
#   'literature',
#   'wrote',
#   'woman',
#   'black',
#   'something',
#   'particulalry',
#   'want',
#   'read',
#   'may',
#   'cry',
#   'shitmyself'],
#  ['ilovedoobz',
#   'patty',
#   'flipping',
#   'new',
#   'today',
#   'northern',
#   'light',
#   'get',
#   'payed',
#   'tomorrow'],
#  ['finished',
#   'rehearsing',
#   'dwhy',
#   '-',
#   'ready',
#   'kendrick',
#   'lamar',
#   'show',
#   'tomorrow',
#   'shout',
#   'out',
#   'wvu',
#   'httpannoyed',
#   'co',
#   'd76r8yzh'],
#  ['posted',
#   '12',
#   'photo',
#   'facebook',
#   'album',
#   'super',
#   'sunday',
#   'wid',
#   'shobhit',
#   'bhatia',
#   'httpannoyed',
#   'co',
#   '9dytiaxo'],
#  ['watching',
#   'all-access',
#   'kentucky',
#   'every',
#   'wed',
#   'making',
#   'like',
#   'young',
#   'dude',
#   'kentucky'],
#  ['nick',
#   'j',
#   'day',
#   '30',
#   'powder',
#   'puff',
#   'pant',
#   'look',
#   'like',
#   "i'm",
#   'gonna',
#   'stud',
#   'tomorrow',
#   'light',
#   'l',
#   'starcevich',
#   'n',
#   'jeffries13'],
#  ['roy',
#   'go',
#   'bigger',
#   'embarassment',
#   'capello',
#   'mcclaren',
#   'httpannoyed',
#   'co',
#   'easmq1m7'],
#  ['black',
#   'friday',
#   'deal',
#   'nikon',
#   'd3200',
#   '24',
#   '2',
#   'megapixels',
#   'digital',
#   'slr',
#   'camera',
#   '18-55mm',
#   'nikkor',
#   'vr',
#   'lens',
#   'black',
#   '&',
#   'nikon',
#   'httpannoyed',
#   'co',
#   'npmjk8uc'],
#  ['han',
#   'mon',
#   'dieu',
#   'le',
#   'remix',
#   'de',
#   'best',
#   'dans',
#   'dream',
#   'high',
#   '2',
#   'je',
#   'meurs',
#   'happydd'],
#  ['want',
#   'miss',
#   'tomorrow',
#   'night',
#   'rj',
#   'moving',
#   'maryland',
#   'soon',
#   'truly',
#   'epic',
#   'set',
#   'planned',
#   'httpannoyed',
#   'co',
#   'nitjia5v'],
#  ['forget',
#   'mitch',
#   'daniel',
#   'going',
#   'steven',
#   "colbert's",
#   'show',
#   'thursday',
#   'think',
#   'come',
#   'topic'],
#  ['bline803rasta',
#   'mane',
#   'gotta',
#   'see',
#   'denzel',
#   'movie',
#   'tomorrow',
#   'shit',
#   'look',
#   'like',
#   'gone',
#   'good',
#   'one',
#   'ditto',
#   'im',
#   'going',
#   'try',
#   'go',
#   'tomorrow'],
#  ['barackobama',
#   'would',
#   'think',
#   'would',
#   'running',
#   'potus',
#   'may',
#   'part',
#   'job',
#   'someday'],
#  ['grammy', 'caleb', 'going', 'freeport', 'tomorrow', 'chalee'],
#  ['kdbowe',
#   'gon',
#   'handle',
#   'announcing',
#   'super',
#   'bowl',
#   'sunday',
#   'might',
#   'put',
#   'gold',
#   'back',
#   'yo',
#   'grill'],
#  ['dapper',
#   'dan1988',
#   'plan',
#   'go',
#   'cv',
#   'work',
#   'today',
#   'get',
#   'something',
#   'may',
#   'get',
#   "i'm",
#   'going',
#   'quarantine',
#   'today'],
#  ['iphone',
#   '5',
#   'apple',
#   'ceo',
#   'pledge',
#   'improve',
#   'new',
#   'map',
#   'app',
#   'apple',
#   'ceo',
#   'tim',
#   'cook',
#   'apologized',
#   'friday',
#   "company's",
#   'er',
#   'httpannoyed',
#   'co',
#   '7dzvgxnz'],
#  ['full',
#   'moon',
#   'oct',
#   '29th',
#   'read',
#   'sun',
#   'sign',
#   'libra',
#   'scorpio',
#   'sag',
#   'cap',
#   'aqua',
#   'pisces',
#   'httpannoyed',
#   'co',
#   'hngb7qn3'],
#  ['drew',
#   'peterson',
#   'may',
#   'convicted',
#   'still',
#   'conflict',
#   'going',
#   'httpannoyed',
#   'co',
#   'lmqkv7xz',
#   'whenwillitend',
#   'localnews',
#   'chicago'],
#  ['wfan660',
#   'paterno',
#   'wouldnt',
#   'charged',
#   'hearsay',
#   'job',
#   'minimal',
#   'may',
#   'reported',
#   'rest',
#   'speculation'],
#  ["benson's",
#   'attention',
#   'frankie',
#   'feel',
#   'like',
#   'forgotten',
#   'stepchild',
#   'let',
#   "'founding",
#   "father'",
#   'know',
#   'never',
#   'forget',
#   '2nd',
#   'place'],
#  ['police',
#   'protester',
#   'clash',
#   'republic',
#   'day',
#   'march',
#   'turkey',
#   'day',
#   'marking',
#   '89th',
#   'anniversary',
#   'founding',
#   'httpannoyed',
#   'co',
#   'xewokaie'],
#  ['participating',
#   'google+',
#   'hangout',
#   'theeconomist',
#   'tomorrow',
#   "i'm",
#   'super',
#   'excited',
#   'check',
#   'httpsannoyed',
#   'co',
#   'jvmzcqba'],
#  ['buckbelue8',
#   'think',
#   'murray',
#   'may',
#   'leave',
#   'way',
#   'team',
#   'draft',
#   '5th',
#   '6th',
#   'round'],
#  ['aww',
#   'love',
#   'austin',
#   'river',
#   'happy',
#   'see',
#   'get',
#   'start',
#   '1st',
#   'nba',
#   'game',
#   'boy',
#   'let',
#   'go',
#   'spur',
#   'spur',
#   'nba'],
#  ['witheredhand',
#   "i've",
#   'paid',
#   'quid',
#   'jim',
#   'white',
#   'record',
#   'recall',
#   'correctly',
#   "i'm",
#   'biz',
#   'may',
#   'well',
#   'missing',
#   'point'],
#  ['teamstradley',
#   'mine',
#   'personal',
#   'thinking',
#   'tebow',
#   'better',
#   'flacco',
#   'care',
#   'bad',
#   'played',
#   'sunday'],
#  ['oilonwhyte',
#   'albertaoilfire',
#   'another',
#   'center',
#   'gagner',
#   'good',
#   'cheap',
#   '2nd',
#   'line',
#   'option',
#   'afford',
#   'keep',
#   'kid'],
#  ['politicalwire',
#   "i'm",
#   'still',
#   'shaking',
#   'head',
#   'decision',
#   'heat',
#   '&',
#   'knick',
#   'actually',
#   'playing',
#   'tomorrow',
#   'msg'],
#  ['glass',
#   'may',
#   'rising',
#   'getting',
#   'warmer',
#   'lago',
#   'del',
#   'desierto',
#   'argentina',
#   'httpannoyed',
#   'co',
#   'hp4s2m5g'],
#  ['wish', 'could', 'make', 'trip', 'athens', 'tuesday', 'icaptainmorgan'],
#  ['apple',
#   'software',
#   'retail',
#   'chief',
#   'overhaul',
#   'san',
#   'francisco',
#   'reuters',
#   '-',
#   'apple',
#   'inc',
#   'ceo',
#   'tim',
#   'cook',
#   'monday',
#   'pushed',
#   'powerful',
#   'hea'],
#  ['want', 'watch', 'grey', '16th', 'time'],
#  ['capello',
#   'say',
#   'time',
#   'russia',
#   'win',
#   'big',
#   'match',
#   'russia',
#   'manager',
#   'fabio',
#   'capello',
#   'thursday',
#   'said',
#   'intended',
#   'httpannoyed',
#   'co',
#   'efc5cfng'],
#  ["i'm",
#   'hosting',
#   'day',
#   'party',
#   'spartacus',
#   'friday',
#   '2-6',
#   'spy',
#   'raleigh',
#   'night'],
#  ['eli',
#   'manning',
#   'hope',
#   'giant',
#   'uplift',
#   'spirit',
#   'million',
#   'affected',
#   'sandy',
#   'ny',
#   'game',
#   'steelers',
#   'sunday'],
#  ['allbelongs2me',
#   'mccormick',
#   'place',
#   'rite',
#   'hyatt',
#   'hotel',
#   'like',
#   '23rd',
#   'nd',
#   'king',
#   'dr'],
#  ['fabio',
#   'capello',
#   "i've",
#   'seen',
#   'day',
#   'assure',
#   'russia',
#   'capable',
#   'getting',
#   'good',
#   'result',
#   'v',
#   'portugal',
#   'tomorrow',
#   'cantwait'],
#  ['bbberb',
#   'necessarily',
#   'nevada',
#   'may',
#   'help',
#   'obama',
#   'one',
#   'le',
#   'vote',
#   'romney',
#   'know',
#   'mean',
#   'hah'],
#  ['parker',
#   'leonard',
#   'steal',
#   "okc's",
#   'thunder',
#   'ninety',
#   'minute',
#   'tipoff',
#   'thursday',
#   'night',
#   'at&t',
#   'center',
#   'oklahoma',
#   'ci',
#   'httpannoyed',
#   'co',
#   'nnjbpswk'],
#  ['kreuzer',
#   '11',
#   'really',
#   'hope',
#   'finish',
#   'trade',
#   'tuesday',
#   'wednesday',
#   'gagner',
#   'real',
#   'solid',
#   'player',
#   'could',
#   'help',
#   'sabre'],
#  ['watching',
#   'campaign',
#   'realized',
#   'step',
#   'brother',
#   'still',
#   'funniest',
#   'ferrell',
#   'movie',
#   'one',
#   '2nd',
#   'place'],
#  ['sherwood12',
#   "he's",
#   'plane',
#   'amsterdam',
#   'bet',
#   "he's",
#   'class',
#   'tomorrow'],
#  ['bethanygarland',
#   'really',
#   'wanna',
#   'go',
#   'one',
#   'thing',
#   'watch',
#   'new',
#   'thing',
#   'channel',
#   '4',
#   'last',
#   'friday',
#   'xx'],
#  ['-may-',
#   'girl',
#   'face',
#   'earth',
#   'find',
#   'channing',
#   'tatum',
#   'attractive',
#   'callmecrazy',
#   'justsayin',
#   'donthateme'],
#  ['obama',
#   'may',
#   'better',
#   'staying',
#   'put',
#   'personally',
#   "i'm",
#   'glad',
#   "he's",
#   'back',
#   'trail-',
#   "he's",
#   'helping',
#   'move',
#   'people',
#   'mitt'],
#  ['cold',
#   'pizza',
#   'mass',
#   'effect',
#   '3',
#   'want',
#   'leg',
#   'healed',
#   'going',
#   'look',
#   'voodoo',
#   'shit',
#   "i'll",
#   'walking',
#   'jumping',
#   'running',
#   'tomorrow'],
#  ['remember',
#   'cupid',
#   'convo',
#   'last',
#   'year',
#   'bomb',
#   'candy',
#   'bar',
#   'liked',
#   'love',
#   'next',
#   "tuesday's",
#   'tr',
#   'httpannoyed',
#   'co',
#   'af9hu4pu'],
#  ['november',
#   '16',
#   'mom',
#   'sister',
#   'going',
#   'see',
#   'breaking',
#   'dawn',
#   'part',
#   '2',
#   'judgeus'],
#  ['channing', 'tatum', 'white', 'oak', 'tomorrow', 'stalker'],
#  ['brett',
#   'elliott8',
#   'fly',
#   'saturday',
#   '15th',
#   'detroit',
#   'amsterdam',
#   'newcastle'],
#  ['dad',
#   '&',
#   'builder',
#   'talking',
#   'city',
#   'turn',
#   'builder',
#   'sat',
#   'row',
#   'behind',
#   'aston',
#   'villa',
#   'game',
#   'fuck',
#   'sake'],
#  ['game', 'played', 'week', 'interesting', 'super', 'sunday'],
#  ['hulu',
#   'video',
#   'game',
#   'trailer',
#   '-',
#   'launch',
#   'trailer',
#   'check',
#   'launch',
#   'trailer',
#   'mass',
#   'effect',
#   '3',
#   'added',
#   'fri',
#   'oct',
#   '26',
#   '00',
#   'httpannoyed',
#   'co',
#   'xsbcpkve'],
#  ['pastorjoshg',
#   'corylethgo',
#   'kevincabe',
#   'kcabe21',
#   "i'd",
#   'watch',
#   'cougar',
#   'town',
#   'day',
#   'january',
#   '8',
#   'tb',
#   'funny',
#   'firedooley'],
#  ['stacie',
#   'hit',
#   'said',
#   'package',
#   'might',
#   'tomorrow',
#   "that's",
#   'case',
#   "i'm",
#   'going',
#   'rave',
#   'san',
#   'fran',
#   'priority'],
#  ['course', 'aston', 'villa', 'played', 'park', 'saturday', 'bring'],
#  ['kevins980',
#   'matching',
#   'cofield',
#   'sack',
#   '1st',
#   'pre-season',
#   'game',
#   "we'll",
#   'see'],
#  ['give',
#   '5',
#   'min',
#   'candy',
#   'dancer',
#   'deja',
#   'vu',
#   "i'm",
#   'nutting',
#   '4th',
#   'pump',
#   'bad',
#   'lol'],
#  ['kevin', 'hart', 'show', 'msg', 'november', '10th', 'going', 'beautiful'],
#  ['heeydems',
#   'know',
#   'may',
#   "we're",
#   'fond',
#   'country',
#   'uh',
#   'happy',
#   'republic',
#   'day'],
#  ['shootingrocks',
#   'cof',
#   'cof~',
#   'someone',
#   'going',
#   'germany',
#   'november',
#   '30',
#   'oh',
#   'really',
#   'envy',
#   'happy',
#   'httpannoyed',
#   'co',
#   'kzzor8az'],
#  ['thank',
#   'snow',
#   'cancelling',
#   'class',
#   'today',
#   'may',
#   'stop',
#   'snowing',
#   'drive',
#   'chapel',
#   'hill',
#   'tomorrow',
#   "i'd",
#   'really',
#   'appreciate'],
#  ['chick',
#   'class',
#   'said',
#   'flacco',
#   'best',
#   'qb',
#   'league',
#   '1-',
#   'chick',
#   'talkin',
#   'football',
#   '2',
#   'cant',
#   'wait',
#   'class',
#   'tomorrow',
#   'lol'],
#  ['entrepreneur',
#   'angelinvestor',
#   'pitch',
#   'new',
#   'birthday',
#   'party',
#   'super',
#   'bowl',
#   'sunday',
#   'treat',
#   'httpannoyed',
#   'co',
#   'hcu3990c'],
#  ['oilersmobile',
#   'july',
#   '20',
#   'sam',
#   'gagner',
#   'httpannoyed',
#   'co',
#   'misqemgq',
#   'gagns89',
#   'nice',
#   'least',
#   'another',
#   'year'],
#  ['think', 'might', 'go', 'see', 'flight', 'tomorrow', 'denzel', 'washington'],
#  ['mohamed',
#   "nasheed's",
#   'press',
#   'brief',
#   'coni',
#   'report',
#   '-',
#   '31',
#   'aug',
#   '2012',
#   'httpannoyed',
#   'co',
#   'nin6zhhn',
#   'via',
#   'youtube'],
#  ['wish',
#   'best',
#   'luck',
#   'boro',
#   'football',
#   'player',
#   'hope',
#   'kick',
#   'butt',
#   'saturday',
#   'shaun',
#   'winitforshaun'],
#  ['calling',
#   'reality',
#   'tv',
#   'fan',
#   "we're",
#   'inviting',
#   'li',
#   'reality',
#   'tv',
#   'star',
#   'join',
#   'google+',
#   'hangout',
#   'sunday',
#   'httpannoyed',
#   'co',
#   'wzo0bhvm'],
#  ['honesty',
#   'often',
#   'best',
#   'policy',
#   'fabio',
#   'capello',
#   'russia',
#   'coach',
#   'hoping',
#   "ronaldo's",
#   'injury',
#   'serious',
#   'play',
#   'tomorrow'],
#  ['bestie',
#   'gotta',
#   'go',
#   'see',
#   'flight',
#   'denzel',
#   'washington',
#   'come',
#   'friday',
#   'seems',
#   'good',
#   'bsociallyactive'],
#  ['know',
#   "y'all",
#   'november',
#   '1',
#   "i'll",
#   'google+',
#   'hangout',
#   'jordy',
#   'nelson',
#   'squeeeeee'],
#  ['dinner',
#   'athens',
#   'friend',
#   'stevebeuerlein',
#   'preparing',
#   'game',
#   'seconcbs',
#   'saturday',
#   'olemiss',
#   'georgia',
#   'httpannoyed',
#   'co',
#   '4qqwxtnd'],
#  ['yvette', 'elena', 'happy', 'def', 'think', 'come', 'tomorrow', 'boy'],
#  ['austin', 'river', '1st', 'game', 'people', 'sucking', 'rookie', 'chill'],
#  ['goatmilkstuff', 'hello', 'may', 'ask', 'get', 'set', 'castle'],
#  ['throwback',
#   'thursday',
#   'daddy',
#   'joe',
#   'pa',
#   'rip',
#   'eye',
#   'still',
#   'winningest',
#   'coach',
#   'college',
#   'footbal',
#   'httpannoyed',
#   'co',
#   'vhjcxzor'],
#  ['hockeyyinsiderr',
#   'oilersnow',
#   "gagner's",
#   'agent',
#   'say',
#   'talk',
#   'continue',
#   'hearing',
#   'friday',
#   'deal',
#   'msm',
#   'proved',
#   'clueless'],
#  ['im',
#   'enjoying',
#   'celebrity',
#   'juice',
#   'instead',
#   'sleep',
#   'going',
#   'fooked',
#   'tomorrow',
#   'though'],
#  ['woman',
#   'black',
#   '-',
#   'legendary',
#   'ghost',
#   'thriller',
#   'touring',
#   'dubai',
#   'abu',
#   'dhabi',
#   'november',
#   '&',
#   'december',
#   'httpannoyed',
#   'co',
#   '2uz56zci'],
#  ['please', 'wednesday', 'potus', 'elected', 'move', 'country', 'forward'],
#  ['jacksonville', 'really', 'sound', 'like', 'move', 'tomorrow'],
#  ['asimplelife',
#   'open',
#   'tomorrow',
#   "lee's",
#   '4-star',
#   'san',
#   'fran',
#   '-',
#   'roger',
#   'ebert',
#   'called',
#   'one',
#   "year's",
#   'best',
#   'film',
#   'httpannoyed',
#   'co',
#   'q0cz0lz6'],
#  ['jessiewagnon',
#   'tcswagg',
#   'nooooooooo',
#   'maybe',
#   'look',
#   'right',
#   'test',
#   'tomorrow',
#   'first'],
#  ['hcafc',
#   'loan',
#   'keeper',
#   'ben',
#   'amos',
#   'named',
#   'england',
#   'under-21s',
#   'side',
#   'face',
#   'azerbaijan',
#   'next',
#   'thursday',
#   'norway',
#   'sept',
#   '10'],
#  ['norv',
#   'turner',
#   'call',
#   'play',
#   'action',
#   'pas',
#   '1st',
#   '&',
#   'goal',
#   'half-yard',
#   'line',
#   'river',
#   'throw',
#   'pick',
#   'charger'],
#  ['celebrity', 'juice', 'best', 'thing', 'thursday'],
#  ['steverattner',
#   'joenbc',
#   'morningmika',
#   'friend',
#   'betting',
#   'joe',
#   'wet',
#   'pant',
#   'see',
#   'whopping',
#   'mitten',
#   'get',
#   'nov',
#   '6'],
#  ['ahmedthalib',
#   'waheed',
#   'proposed',
#   'mdp',
#   'join',
#   'gov',
#   'prior',
#   "coni's",
#   'verdict',
#   '7',
#   'feb',
#   'controversial',
#   'power',
#   'transfer',
#   'refrained',
#   'mdp',
#   'joining',
#   'govt'],
#  ['hayleyrose',
#   'booked',
#   'see',
#   'good',
#   'day',
#   'die',
#   'hard',
#   'february',
#   '14',
#   '2013',
#   "valentine's",
#   'day'],
#  ['amianatyransky',
#   'frankie',
#   'think',
#   "i'm",
#   'gonna',
#   'date',
#   'bed',
#   'tomorrow',
#   "that's",
#   'boy'],
#  ['pray',
#   'mohamed',
#   'morsi',
#   'new',
#   'president',
#   'egypt',
#   'may',
#   'continue',
#   'leader',
#   'freedom',
#   'peace',
#   'httpannoyed',
#   'co',
#   'f0lkm17i'],
#  ['may',
#   'spend',
#   'lot',
#   'free',
#   'time',
#   'riding',
#   'random',
#   'elevator',
#   'hoping',
#   'chance',
#   'encounter',
#   'bill',
#   'murray'],
#  ['wvu', 'go', 'every', '4th', 'kicker', 'worst', 'cundiff'],
#  ['rhayne', 'mac1', 'becky', 'cause', 'told', "i'll", 'figure', 'tomorrow'],
#  ['axl', 'rose', 'need', 'give', 'later', 'soon', 'tomorrow'],
#  ['dr',
#   'mohamed',
#   'morsi',
#   'announced',
#   "egypt's",
#   '1st',
#   'elected',
#   'president',
#   'glorious',
#   '25th',
#   'jan',
#   'revolution',
#   'congratulation',
#   'egypt',
#   'happy'],
#  ['shout',
#   'boy',
#   'jshapmma',
#   'fight',
#   'tomorrow',
#   'night',
#   'la',
#   'vega',
#   'rfa',
#   'card',
#   "he's",
#   'put',
#   'work',
#   'need',
#   'wish',
#   'luck'],
#  ['lore',
#   'x3',
#   'dec',
#   '16th',
#   'know',
#   'far',
#   'near',
#   'end',
#   'sagittarius',
#   "i'm",
#   'full',
#   'blown',
#   'sag',
#   'girl',
#   'happy',
#   'lol'],
#  ['isle',
#   'man',
#   'next',
#   'thurs',
#   "i'll",
#   'talking',
#   'safe',
#   'house',
#   'signing',
#   'book',
#   'waterstones',
#   '6',
#   '30pm',
#   'waterstonesiom'],
#  ['pbr',
#   '&',
#   'mokbpresents',
#   'bring',
#   'jim',
#   'white',
#   'do317',
#   'lounge',
#   'october',
#   '23rd',
#   '7',
#   'pm',
#   'httpannoyed',
#   'co',
#   '7x8ofc56'],
#  ['happy',
#   'halloween',
#   'starting',
#   'wicked',
#   'wednesday',
#   'listening',
#   'pink',
#   'floyd',
#   'leonard',
#   'cohen',
#   'get',
#   'take',
#   'boy',
#   'tonight',
#   'yay'],
#  ['wonder',
#   'cortese',
#   'thinking',
#   'watching',
#   '1st',
#   'half',
#   'total',
#   'wank',
#   'boruc',
#   'disgrace',
#   'complete',
#   'twat',
#   'saintsfc'],
#  ['sad',
#   'get',
#   'see',
#   'zachmtv',
#   'challenge',
#   'battle',
#   'season',
#   'tonight',
#   'sad',
#   'guess',
#   "i'll",
#   'wait',
#   'next',
#   'wednesday'],
#  ['austin',
#   'river',
#   'need',
#   'get',
#   'stronger',
#   'spur',
#   'guard',
#   'muscling',
#   'tonight',
#   'started',
#   'scored',
#   '4th',
#   'hornet'],
#  ['july',
#   '28th',
#   'national',
#   'milk',
#   'chocolate',
#   'day',
#   'might',
#   'say',
#   'milk',
#   'chocolate',
#   'star',
#   'chocolate',
#   'cont',
#   'httpannoyed',
#   'co',
#   'gebog3gl'],
#  ['sunday',
#   'november',
#   '4th',
#   'olympus',
#   'expert',
#   'hand',
#   'curry',
#   'store',
#   'cambridge',
#   '10',
#   '30am',
#   'httpannoyed',
#   'co',
#   'skd7nloy'],
#  ['happy',
#   'valentine',
#   'day',
#   '<3',
#   'live',
#   'brazil',
#   'otherwise',
#   'another',
#   'irritating',
#   'monday'],
#  ['okay',
#   'megnicolelewis',
#   'watch',
#   'woman',
#   'black',
#   'may',
#   'terrible',
#   'night'],
#  ['real',
#   'liam',
#   'payne',
#   'saturday',
#   'buy',
#   'ticket',
#   'tmhtour',
#   'belgium',
#   "i'm",
#   'happy'],
#  ['go',
#   'way',
#   'fast',
#   'already',
#   'year',
#   'saw',
#   'avril',
#   'lavigne',
#   'concert',
#   '<3',
#   'october',
#   '25',
#   '2011',
#   'one',
#   'best',
#   'day',
#   'life',
#   'happy'],
#  ['heh',
#   'remembered',
#   'forgot',
#   'watch',
#   'jonathan',
#   'ross',
#   'guess',
#   "i'll",
#   'watch',
#   'tomorrow',
#   'watching',
#   'another',
#   'show',
#   'forgot',
#   'schmeh'],
#  ['gambled',
#   'chocolate',
#   'day',
#   'successful',
#   'theme',
#   'day',
#   'work',
#   'turn',
#   'chdn',
#   'like',
#   'chocolate',
#   'wed',
#   'gross',
#   'day',
#   'hope',
#   'kid',
#   'like',
#   'gross',
#   'stuff'],
#  ['harry',
#   'redknapp',
#   'set',
#   'hold',
#   'talk',
#   'blackburn',
#   'job',
#   'tuesday',
#   'prepares',
#   'return',
#   'management',
#   'mail'],
#  ['supremejuice',
#   'go',
#   'bell',
#   'game',
#   'tomorrow',
#   "i'll",
# ...
#   'thanksgiving',
#   'week',
#   'away',
#   'world',
#   'series',
#   'ended',
#   'sund',
#   'httpannoyed',
#   'co',
#   '8dgziecz'],
#  ['domeqwwfv1',
#   'may',
#   'true',
#   'becouse',
#   'triple',
#   'h',
#   'arm',
#   'broken',
#   'reel',
#   'may',
#   'come',
#   'back',
#   'royal',
#   'rumble'],
#  ['thexfactor',
#   'boring',
#   'xfactor',
#   'seen',
#   'xfactor',
#   'itv1',
#   "let's",
#   'something',
#   'new',
#   'autumn',
#   'dancing',
#   'ice',
#   'january'],
#  ['went',
#   'see',
#   "'the",
#   'mystery',
#   'charles',
#   "dickens'",
#   'playhouse',
#   'theatre',
#   'west',
#   'end',
#   'last',
#   'thursday',
#   'starring',
#   'simon',
#   'callow',
#   'must',
#   'see'],
#  ['oh',
#   'yay',
#   'mom',
#   'told',
#   'grammy',
#   'coming',
#   'tomorrow',
#   'woot',
#   'woot',
#   'loveher'],
#  ['unfortunately',
#   'wathcing',
#   'manifestation',
#   'related',
#   'republic',
#   'day',
#   'see',
#   'really',
#   'far',
#   'away',
#   '21st',
#   'century',
#   '+++'],
#  ['may',
#   'little',
#   'forward',
#   '-',
#   'secret-country',
#   'imagine',
#   'sex',
#   'miranda',
#   'lambert',
#   '&',
#   'blake',
#   'httpannoyed',
#   'co',
#   'qheebjn4'],
#  ['ending',
#   'grey',
#   'may',
#   'one',
#   'bad',
#   'as',
#   'ending',
#   'movie',
#   "i've",
#   'ever',
#   'seen'],
#  ['totally',
#   'curious',
#   'dream',
#   'high',
#   '2',
#   'wanna',
#   'watch',
#   'drama',
#   'asap',
#   'wanna',
#   'compare',
#   '1st',
#   'one',
#   'still',
#   'there',
#   'loooooooong',
#   'holiday'],
#  ['safe',
#   'sound',
#   'narita',
#   'airport',
#   'feel',
#   'good',
#   'back',
#   'land',
#   'rising',
#   'sun'],
#  ['early',
#   'germany',
#   'american',
#   'friend',
#   'getting',
#   'drunk',
#   'prague',
#   'knucklehead',
#   'talk',
#   'sunday',
#   'czechrep'],
#  ['chicagobears',
#   'let',
#   'let',
#   'game',
#   'sunday',
#   'houston',
#   'san',
#   'fran',
#   'coming',
#   'gotta',
#   'focus',
#   'beating',
#   'tennessee',
#   'jayisourqb'],
#  ["who's", 'going', 'israel', 'saturday'],
#  ['iran',
#   'army',
#   'monitoring',
#   'ship',
#   'gulf',
#   'tehran',
#   'oct',
#   '28',
#   'senior',
#   'commander',
#   'islamic',
#   'revolution',
#   'guard',
#   'corp',
#   'httpannoyed',
#   'co',
#   'uu6vxk2a'],
#  ['soul',
#   'train',
#   "70's",
#   'halloween',
#   'party',
#   'sat',
#   'oct',
#   '27',
#   'httpannoyed',
#   'co',
#   'iruw87sm',
#   'adv',
#   'tixx',
#   '10',
#   '-',
#   '15',
#   'wt',
#   'costume',
#   '20',
#   'door',
#   'httpannoyed',
#   'co',
#   'irj3lznw'],
#  ['nickiminaj',
#   'cant',
#   'wait',
#   'come',
#   'dublin',
#   'monday',
#   'excited',
#   'see',
#   '-',
#   '<3'],
#  ['bj',
#   'penn',
#   'v',
#   'nick',
#   'diaz',
#   'replay',
#   'fueltv',
#   "i'd",
#   'pay',
#   'watch',
#   '2nd',
#   'time'],
#  ['taylor',
#   'swift',
#   'co-host',
#   'grammys',
#   'cool',
#   'j',
#   'new',
#   'york',
#   'oct',
#   '30',
#   'ani',
#   'taylor',
#   'swift',
#   'chosen',
#   'present',
#   'httpannoyed',
#   'co',
#   '3dbmx4jq'],
#  ['hormone',
#   'spiral',
#   'control',
#   'cry',
#   'jeremy',
#   'kyle',
#   'show',
#   '1st',
#   '2nd',
#   '3rd',
#   'time',
#   'today',
#   'wut'],
#  ['danicook8',
#   'ah',
#   'okay',
#   'hoping',
#   'see',
#   'friday',
#   'next',
#   'time',
#   "i'm",
#   'staying',
#   "harry's",
#   'meet',
#   'kingston',
#   'xx'],
#  ['arianacurdles',
#   'lol',
#   'mean',
#   'pronounce',
#   'idk',
#   'either',
#   'hmm',
#   'like',
#   'say',
#   'like',
#   "'hair-may'",
#   "'hair-mess'",
#   'lmfao',
#   'idk',
#   'okay',
#   'xd'],
#  ['stephyyboo15',
#   'lol',
#   'maybe',
#   'friday',
#   'since',
#   "i'm",
#   'going',
#   'georgetown'],
#  ['bird',
#   'wire',
#   'one',
#   '1st',
#   'song',
#   'learned',
#   'child',
#   'daddy',
#   'go',
#   'see',
#   'leonard',
#   'cohen',
#   'httpannoyed',
#   'co',
#   'pvanspi6'],
#  ['jklittle6',
#   'next',
#   'thursday',
#   'friday',
#   'play',
#   'maryland',
#   'new',
#   'york',
#   'first',
#   'real',
#   'game'],
#  ['sure',
#   'watch',
#   'cougar',
#   'town',
#   'friend',
#   'minus',
#   'best',
#   'actor',
#   'plus',
#   'wine',
#   'coming',
#   'january',
#   'right',
#   "shovin'",
#   'buddy'],
#  ['arsenal',
#   'lady',
#   '0-0',
#   'ht',
#   'ffc',
#   'turbine',
#   'potsdam',
#   "women's",
#   'champion',
#   'league',
#   'last',
#   '16',
#   '1st',
#   'leg',
#   'clash',
#   'borehamwood',
#   'wucl'],
#  ['thursday', 'night', 'wont', 'without', 'waterloo', 'road'],
#  ['harden',
#   'got',
#   '25pts',
#   '3rd',
#   'damn',
#   'maybe',
#   'lin',
#   'harden',
#   'get',
#   'rocket',
#   'playoff'],
#  ['everyone',
#   'image',
#   'sexy',
#   'plenty',
#   'men',
#   'may',
#   'think',
#   "i'm",
#   'built',
#   'like',
#   'ray',
#   'lewis',
#   'wit',
#   'weave',
#   'oh',
#   'well'],
#  ["valentine's",
#   'day',
#   'linkin',
#   'park',
#   'may',
#   'newest',
#   'song',
#   'one',
#   'best'],
#  ['community',
#   'cougar',
#   'town',
#   'friday',
#   'night',
#   'light',
#   'glee',
#   'mad',
#   'men',
#   'modern',
#   'family',
#   'six',
#   'feets',
#   'skin',
#   'terra',
#   'nova',
#   'wire'],
#  ['land',
#   'conservation',
#   'announcement',
#   'monday',
#   'gov',
#   'mitch',
#   'daniel',
#   'lt',
#   'gov',
#   'becky',
#   'skillman',
#   'make',
#   'lan',
#   'httpannoyed',
#   'co',
#   '5srsx6j1',
#   'nashville'],
#  ['ryan',
#   'reynolds',
#   'may',
#   'back',
#   'prequel',
#   'sequel',
#   'safe',
#   'house',
#   'without',
#   'denzel',
#   'washington',
#   'script',
#   'work'],
#  ['giselleco',
#   'oh',
#   'hey',
#   'another',
#   'reason',
#   'national',
#   'chocolate',
#   'day',
#   'sunday',
#   'happy'],
#  ['dinner',
#   'dad',
#   'tony',
#   'parker',
#   'last',
#   'second',
#   'game',
#   'winning',
#   'shot',
#   'great',
#   'night',
#   'time',
#   'ruined',
#   '300s',
#   'tomorrow'],
#  ['post',
#   'night',
#   'anonymous',
#   'id',
#   'excv6jkr',
#   '11',
#   '02',
#   '12',
#   'fri',
#   '00',
#   '52',
#   '39',
#   '434329650',
#   'thread',
#   'like',
#   'watching',
#   'monkey',
#   'fuck',
#   'coconut'],
#  ['apple',
#   'ceo',
#   'apologizes',
#   'error-ridden',
#   'new',
#   'map',
#   'app',
#   '+video',
#   'apple',
#   'ceo',
#   'tim',
#   'cook',
#   'apologized',
#   'friday',
#   'company',
#   'httpannoyed',
#   'co',
#   'dphhfypj'],
#  ['bballsource',
#   'got',
#   'completely',
#   'utterly',
#   'lost',
#   'like',
#   'viable',
#   '2nd',
#   'option',
#   'everyone',
#   'knew',
#   "parker's",
#   'shot'],
#  ['congrats',
#   "dj's",
#   '3rd',
#   'grade',
#   'team',
#   'going',
#   'superbowl',
#   "i'll",
#   'cheering'],
#  ["who's", 'going', 'go', 'see', 'breaking', 'dawn', 'part', '2', "c'mon"],
#  ['two',
#   'luke',
#   'austen',
#   'dickens',
#   'playing',
#   'nelson',
#   'bay',
#   'digger',
#   'club',
#   'friday',
#   '2',
#   '11',
#   'go',
#   'check',
#   "'em",
#   'live',
#   'area'],
#  ['janineturner',
#   'yes',
#   'thank',
#   'janine',
#   'saw',
#   'kelsey',
#   'grammer',
#   'wed',
#   'night',
#   'sag',
#   'talk',
#   'politics',
#   "let's",
#   'take',
#   'hollywood',
#   'back'],
#  ['1st',
#   'official',
#   'release',
#   'stripesrecords',
#   'eott2',
#   "rmx's",
#   'haze',
#   '&',
#   'northern',
#   'light',
#   '+',
#   'instrumentals',
#   'httpsannoyed',
#   'co',
#   'xujedhde'],
#  ['big',
#   'game',
#   'miamiheat',
#   'tomorrow',
#   'away',
#   'v',
#   'knicks',
#   'msg',
#   'personally',
#   'think',
#   'knicks',
#   'win',
#   'first',
#   'game',
#   'msg',
#   'crowd',
#   'sandy',
#   'disaster'],
#  ['lot',
#   'rumor',
#   'oiler',
#   'said',
#   'want',
#   'leopold',
#   'adam',
#   '3rd',
#   'sekera',
#   'pysyk',
#   '2nd',
#   'sekera',
#   'adam',
#   'leopold',
#   'adam',
#   'sam',
#   'gagner',
#   'know'],
#  ['second',
#   'last',
#   'show',
#   'season',
#   '19th',
#   'annual',
#   'gift',
#   'art',
#   'artist',
#   'kanata',
#   'civic',
#   'art',
#   'gallery',
#   'stop',
#   'httpannoyed',
#   'co',
#   'bkqnxec0'],
#  ["i'm",
#   'assuming',
#   'heb',
#   'ran',
#   'candy',
#   'people',
#   'decided',
#   'give',
#   'pizza',
#   'instead',
#   'busier',
#   'super',
#   'bowl',
#   'sunday',
#   'today'],
#  ['goodnight',
#   'big',
#   'day',
#   'tomorrow',
#   "i'm",
#   'school',
#   '3',
#   '00',
#   'argentina',
#   'time',
#   'stay',
#   'mallin',
#   'tomorrow',
#   "i'll",
#   'tell'],
#  ['today', 'national', 'kissing', 'day', 'coz', 'work', 'day', 'tomorrow'],
#  ['come',
#   'meet',
#   'member',
#   '1980',
#   'dawgs',
#   'athens',
#   'weekend',
#   'red',
#   'zone',
#   'friday',
#   '3pm',
#   '-',
#   '6pm',
#   'coach',
#   'vince',
#   'httpannoyed',
#   'co',
#   'vq6ykuqc'],
#  ['time',
#   'tomorrow',
#   'night',
#   'ill',
#   'partying',
#   'chapel',
#   'hill',
#   'happy',
#   'cantwait'],
#  ['victor',
#   'cruz',
#   'isnt',
#   'today',
#   'know',
#   "he'll",
#   'get',
#   'together',
#   '2nd',
#   'half'],
#  ['6',
#   'people',
#   'left',
#   'world',
#   'one',
#   'bill',
#   'murray',
#   "there's",
#   '5',
#   'people',
#   "who's",
#   '6th'],
#  ["dublin's",
#   'street',
#   'pub',
#   'come',
#   'join',
#   'u',
#   'open',
#   'mic',
#   'thursday',
#   'party',
#   'continues',
#   'dublin',
#   'street',
#   'pub',
#   'cont',
#   'httpannoyed',
#   'co',
#   'b0fezmlt'],
#  ['oh', 'man', 'thought', 'deadline', 'act', 'tomorrow', '9th', 'bless'],
#  ['keimtime3',
#   'realize',
#   'mizzou',
#   'made',
#   't-shirt',
#   'celebrating',
#   'win',
#   'kentucky',
#   'commemorate',
#   '8th',
#   'place',
#   'finish',
#   'back'],
#  ['1st', 'movie', 'night', 'vow'],
#  ['tt',
#   'participate',
#   'love',
#   'asia',
#   'tomorrow',
#   '2',
#   '11',
#   '2',
#   '30pm',
#   'kst',
#   'kb',
#   'broadcast',
#   'program',
#   '3',
#   '11',
#   '7',
#   '30pm',
#   'kst',
#   'kb',
#   'world'],
#  ['milan-genoa',
#   '22',
#   'rossoneri',
#   'milanello',
#   '-',
#   '22',
#   'player',
#   'called',
#   'milan-genoa',
#   'tomorrow',
#   'san',
#   'siro',
#   'httpannoyed',
#   'co',
#   'u8sz4fji'],
#  ['nml',
#   'muchmusic',
#   'called',
#   'people',
#   'yet',
#   'bruno',
#   'mar',
#   'next',
#   'friday'],
#  ['trying',
#   'ticket',
#   "tomorrow's",
#   'show',
#   'late',
#   'show',
#   'david',
#   'letterman',
#   'httpannoyed',
#   'co',
#   'ei4dinha'],
#  ['ca',
#   'tar',
#   'addicted',
#   'act',
#   'took',
#   'one',
#   'saturday',
#   'signed',
#   'third',
#   'test'],
#  ['27',
#   'hour',
#   'know',
#   'im',
#   'gonna',
#   'see',
#   'boy',
#   'live',
#   'may',
#   '1st',
#   'omgg',
#   'im',
#   'sooo',
#   'scared',
#   'tomorrow'],
#  ['thomaserdbrink',
#   'obama',
#   'win',
#   'quite',
#   'sure',
#   'one',
#   '1st',
#   'major',
#   'foreign',
#   'policy',
#   'hit',
#   'would',
#   'successful',
#   'resumption',
#   'talk',
#   'tehran'],
#  ['awesome',
#   'response',
#   'guy',
#   'correct',
#   'answer',
#   'sam',
#   'gagner',
#   'brendan',
#   'smith',
#   'put',
#   'draw',
#   'coming',
#   'thursday',
#   'jt'],
#  ['harry',
#   'style',
#   'leaving',
#   'one',
#   'direction',
#   'going',
#   'form',
#   'two-man',
#   'band',
#   'ed',
#   '31st',
#   'february',
#   "i'm",
#   'married',
#   'obama'],
#  ['want',
#   'tip',
#   'hand',
#   'move',
#   "portfolio's",
#   'tomorrow',
#   'morning',
#   '8',
#   '35',
#   'cst',
#   'home',
#   'run',
#   'follow'],
#  ['wardchanning',
#   'hey',
#   'channing',
#   'tony',
#   'provias',
#   'aberdeen',
#   'hope',
#   'get',
#   'sack',
#   'murray',
#   'sat'],
#  ['charles',
#   'sings',
#   'lorenzo',
#   'beasley',
#   'killed',
#   'july',
#   '17th',
#   'last',
#   'year',
#   'corner',
#   '53rd',
#   'king',
#   'dr',
#   '~',
#   'mile',
#   '5'],
#  ['tl',
#   'guy',
#   'talk',
#   'afc',
#   'v',
#   'mufc',
#   'know',
#   'guy',
#   'u',
#   'cant',
#   'wait',
#   'till',
#   'saturday',
#   'happy',
#   'epl',
#   '<33'],
#  ['second',
#   'time',
#   'eagle',
#   'make',
#   'stop',
#   '--',
#   'commit',
#   'penalty',
#   'pi',
#   'kendricks',
#   'give',
#   'atl',
#   'another',
#   '1st',
#   'groundhog',
#   'day',
#   'life'],
#  ['ama',
#   'la',
#   'lettura',
#   'would',
#   'full',
#   'day',
#   'movie',
#   'mine',
#   'thursday',
#   'p',
#   'far',
#   'tarzan',
#   'notebook',
#   'list',
#   'xd'],
#  ['like',
#   'sweet',
#   'happy',
#   'valentine',
#   'day',
#   'july',
#   "i'll",
#   'meet',
#   'shop',
#   'every',
#   'tuesday'],
#  ['dabieberbreezy',
#   'queen',
#   'please',
#   'help',
#   'trend',
#   'biebsmeetbieberwhirls',
#   "he's",
#   'coming',
#   'city',
#   'tomorrow',
#   '&',
#   'wanna',
#   'try',
#   'meet'],
#  ['watched',
#   'muse',
#   'jonathan',
#   'ross',
#   'show',
#   'last',
#   'night',
#   'promptly',
#   'nightmare',
#   'screwing',
#   'everything',
#   'wednesday',
#   'eeeeek'],
#  ['morgwolfe',
#   'jillianlucas3',
#   'mack',
#   'may',
#   'movie',
#   'friday',
#   'night',
#   'flight',
#   'denzel',
#   'washington',
#   'make',
#   'plan',
#   'made',
#   'plan'],
#  ['hope',
#   'go',
#   'niner',
#   'game',
#   'onda',
#   '11th',
#   'mind',
#   "meetin'",
#   'widd',
#   'boo',
#   'kyle',
#   'williams',
#   'inda',
#   'loccer',
#   'room',
#   '&',
#   'stuff',
#   'lmfao'],
#  ['river',
#   'gate',
#   '3rd',
#   'time',
#   'season',
#   'keep',
#   'chief',
#   'fantasy',
#   'team',
#   'need'],
#  ['arianators',
#   'please',
#   'help',
#   "i'm",
#   'girl',
#   "who's",
#   'body',
#   'sore',
#   'asking',
#   'ariana',
#   '&',
#   "jennette's",
#   'goodluck',
#   'tomorrow',
#   'please',
#   'sad'],
#  ['google+',
#   'hangout',
#   'october',
#   '27th',
#   '2pm',
#   'pacific',
#   '5pm',
#   'eastern',
#   'via',
#   'askllcoolj',
#   'llcooljhangout',
#   'httpannoyed',
#   'co',
#   'jbkwsfgd',
#   'kpoptv',
#   '2pm'],
#  ['ac',
#   'milan',
#   'reportedly',
#   'want',
#   'miralem',
#   'pjanic',
#   'join',
#   'san',
#   'siro',
#   'january',
#   'source',
#   'corriere',
#   'dello',
#   'sport',
#   'httpannoyed',
#   'co',
#   '1onyaoxn',
#   'transfertalk'],
#  ['gotta',
#   'remember',
#   'bring',
#   'dionje',
#   'candy',
#   'tomorrow',
#   'lol',
#   'got',
#   'mad',
#   'today'],
#  ['great',
#   'drink',
#   'special',
#   'saturday',
#   'mizzou',
#   'look',
#   'upset',
#   'florida',
#   'former',
#   'mizzou',
#   'wr',
#   'brian',
#   'wheller',
#   'httpannoyed',
#   'co',
#   'xokdqwas'],
#  ['watched',
#   'vow',
#   '5th',
#   'time',
#   "i'm",
#   'still',
#   'tearing',
#   "what's",
#   'wrong',
#   'movie',
#   'tooo',
#   'omg',
#   "can't",
#   'even'],
#  ['see',
#   'march',
#   '24th',
#   'argentina',
#   'miami',
#   'limit',
#   'asot',
#   'arminvanbuuren'],
#  ['rlbrown3', 'better', 'suit', 'senior', 'bowl', 'friday', 'night'],
#  ['egypt&',
#   '039',
#   'president',
#   'mohamed',
#   'morsi',
#   'monday',
#   'pardoned',
#   'arrested',
#   'start',
#   'revolution',
#   'httpannoyed',
#   'co',
#   'emfvhotu'],
#  ['kurt',
#   'convey',
#   'win',
#   'boy',
#   'race',
#   '16',
#   '01',
#   'nick',
#   'diaz',
#   'coming',
#   '2nd',
#   'around',
#   '16',
#   '10',
#   'rounding',
#   'top',
#   '3',
#   'kenny',
#   'castro'],
#  ['fyi',
#   '-',
#   'ridiculously',
#   'adorable',
#   'ladybug',
#   'larry',
#   'bird',
#   'give',
#   '1st',
#   'piece',
#   'candy',
#   'producer',
#   'director',
#   'chris',
#   "koch's",
#   'gorgeous',
#   'daughter'],
#  ['picture',
#   'overdoser',
#   '1st',
#   'anniversary',
#   'party',
#   'safe',
#   'house',
#   'thonglor',
#   'online',
#   'check',
#   'httpannoyed',
#   'co',
#   'owjm4swu',
#   'httpannoyed',
#   'co',
#   'ymeq9krl'],
#  ['realized',
#   "i've",
#   'spent',
#   'halloween',
#   'super',
#   'bowl',
#   'sunday',
#   'last',
#   'two',
#   'birthday',
#   'either',
#   'library',
#   'computer',
#   'lab'],
#  ['busted',
#   'birch',
#   'caught',
#   'celebrating',
#   "1st'a",
#   'cup',
#   'win',
#   'andy',
#   'carroll',
#   'joe',
#   'hart',
#   'beer',
#   'jager',
#   'httpannoyed',
#   'co',
#   'ifv3wd9i'],
#  ['patwgr',
#   'still',
#   'looking',
#   'center',
#   'may',
#   'want',
#   'inquire',
#   'sam',
#   'gagner',
#   'edmonton',
#   'need'],
#  ['enjoyed',
#   'flotus',
#   'today',
#   'fl',
#   'michelleobama',
#   'u',
#   'r',
#   'brilliant',
#   'simply',
#   'put',
#   'glad',
#   'voted',
#   'saturday',
#   'obama2012',
#   'duval',
#   'httpannoyed',
#   'co',
#   '0szz0xm7'],
#  ["tonight's",
#   'never',
#   'mind',
#   'buzzcocks',
#   'hilarious',
#   'noel',
#   'fielding',
#   'happy',
#   "can't",
#   'wait',
#   'download',
#   'tomorrow'],
#  ['top',
#   'ten',
#   'striker',
#   'premier',
#   "league's",
#   'january',
#   'wishlist',
#   'httpannoyed',
#   'co',
#   'bbn99w2d',
#   'via',
#   'footballfancast'],
#  ['police',
#   'surgery',
#   'fri',
#   'penygraig',
#   'resident',
#   'boys&girls',
#   'club',
#   '9am',
#   '11am',
#   'pop',
#   'along',
#   'meet',
#   'local',
#   'officer',
#   'httpannoyed',
#   'co',
#   'pvo8ua62',
#   'md'],
#  ['would',
#   'like',
#   'see',
#   'cornerback',
#   'champ',
#   'bailey',
#   'play',
#   'twelfth',
#   'pro',
#   'bowl',
#   'january',
#   '2013',
#   'pro',
#   'bowl',
#   'voting',
#   'httpannoyed',
#   'co',
#   'zna416fc'],
#  ['taking',
#   'litre',
#   'fizzy',
#   'flavoured',
#   'water',
#   'bed',
#   'tonight',
#   'super',
#   'sunday',
#   'gonna',
#   'result',
#   'mouth',
#   'like',
#   "ghandi's",
#   'flip',
#   'flop',
#   'gacky',
#   'rank',
#   'beer'],
#  ['cant',
#   'wait',
#   'see',
#   'flight',
#   'saturday',
#   'denzel',
#   'one',
#   'best',
#   'actor',
#   'world',
#   'alongside',
#   'leo',
#   'de',
#   'niro'],
#  ['ben',
#   'higham',
#   'put',
#   '2nd',
#   'team',
#   'get',
#   'beat',
#   'go',
#   'rafa',
#   'behave',
#   'ben',
#   'sound',
#   'like',
#   'wool',
#   'calling',
#   'rafa'],
#  ['caitrob89', 'going', 'mizzou', 'game', 'saturday', "kaleb's", 'family'],
#  ["y'all",
#   'know',
#   'halloween',
#   'candy',
#   'gonna',
#   'clearance',
#   'tomorrow',
#   'save',
#   "valentine's",
#   'day',
#   'happy'],
#  ['city',
#   'game',
#   'raven',
#   'stadium',
#   'saturday',
#   'noon',
#   '10',
#   'dollar',
#   'get',
#   'else',
#   'going'],
#  ...]

# %% [markdown]
# **Unindo tokenização ao dataframe novamente**

# %%
dataframe["Tokenized text"]=final_tweets

# %%
dataframe
# Out:
#                       id  polarity  \
# 0     264183816548130816  positive
# 1     263405084770172928  negative
# 2     262163168678248449  negative
# 3     264249301910310912  negative
# 4     262682041215234048   neutral
# ...                  ...       ...
# 9679  103158179306807296  positive
# 9680  103157324096618497  positive
# 9681  100259220338905089   neutral
# 9682  104230318525001729  positive
# 9683  100461938533863424  negative
#
#                                                    text  \
# 0     Gas by my house hit $3.39!!!! I\u2019m going t...
# 1     Theo Walcott is still shit\u002c watch Rafa an...
# 2     its not that I\u2019m a GSP fan\u002c i just h...
# 3     Iranian general says Israel\u2019s Iron Dome c...
# 4     Tehran\u002c Mon Amour: Obama Tried to Establi...
# ...                                                 ...
# 9679  RT @MNFootNg It's monday and Monday Night Foot...
# 9680  All I know is the road for that Lomardi start ...
# 9681  All Blue and White fam, we r meeting at Golden...
# 9682  @DariusButler28   Have a great game agaist Tam...
# 9683  I'm pisseeedddd that I missed Kid Cudi's show ...
#
#                                          Tokenized text
# 0     [gas, house, hit, 3, 39, i'm, going, chapel, h...
# 1     [theo, walcott, still, shit, watch, rafa, john...
# 2     [i'm, gsp, fan, hate, nick, diaz, can't, wait,...
# 3     [iranian, general, say, israel's, iron, dome, ...
# 4     [tehran, mon, amour, obama, tried, establish, ...
# ...                                                 ...
# 9679  [mnfootng, monday, monday, night, football, mi...
# 9680  [know, road, lomardi, start, tonight, set, rec...
# 9681  [blue, white, fam, r, meeting, golden, corral,...
# 9682  [dariusbutler28, great, game, agaist, tampa, b...
# 9683  [i'm, pisseeedddd, missed, kid, cudi's, show, ...
#
# [9684 rows x 4 columns]

# %%
#ocorrencia de cada palavra
dicio
# Out:
# {'gas': 8,
#  'house': 118,
#  'hit': 59,
#  '3': 224,
#  '39': 5,
#  "i'm": 621,
#  'going': 754,
#  'chapel': 11,
#  'hill': 19,
#  'sat': 206,
#  'happy': 647,
#  'theo': 3,
#  'walcott': 2,
#  'still': 235,
#  'shit': 79,
#  'watch': 247,
#  'rafa': 11,
#  'johnny': 9,
#  'deal': 37,
#  'saturday': 529,
#  'gsp': 2,
#  'fan': 44,
#  'hate': 38,
#  'nick': 43,
#  'diaz': 10,
#  "can't": 236,
#  'wait': 236,
#  'february': 85,
#  'iranian': 2,
#  'general': 8,
#  'says': 87,
#  "israel's": 4,
#  'iron': 7,
#  'dome': 2,
#  'missiles': 1,
#  'keep': 52,
#  'talking': 35,
#  'like': 491,
#  'may': 871,
#  'end': 90,
#  'finding': 3,
#  'tehran': 10,
#  'mon': 28,
#  'amour': 1,
#  'obama': 63,
#  'tried': 9,
#  'establish': 1,
#  'ties': 2,
#  'mullahs': 1,
#  'httpannoyed': 2142,
#  'co': 2040,
#  'tzzzrrka': 1,
#  'via': 75,
#  'pjmedia': 1,
#  'com': 35,
#  'barack': 6,
#  '-': 741,
#  'vote': 50,
#  'mitt': 19,
#  'romney': 14,
#  'whole': 32,
#  'movie': 113,
#  'harry': 32,
#  'ron': 10,
#  'christmas': 35,
#  'ohlawd': 1,
#  'j': 28,
#  'davlar': 1,
#  '11th': 34,
#  'main': 25,
#  'rivals': 3,
#  'team': 141,
#  'poland': 12,
#  'hopefully': 38,
#  'make': 249,
#  'successful': 5,
#  'tough': 18,
#  'week': 122,
#  'training': 25,
#  'tomorrow': 1747,
#  "act's": 2,
#  '&&': 7,
#  "sat's": 6,
#  'deciding': 3,
#  'want': 249,
#  'go': 464,
#  'college': 42,
#  'applying': 2,
#  'colleges': 1,
#  'everything': 30,
#  'stresses': 1,
#  'valentines': 21,
#  'day': 858,
#  'trending': 19,
#  '14th': 36,
#  '12th': 16,
#  'june': 48,
#  'smh': 19,
#  'superbowl': 22,
#  'dallas': 48,
#  "ain't": 18,
#  'winning': 26,
#  'quarterback': 2,
#  'owner': 6,
#  's4nyc': 1,
#  'rasmussenpoll': 1,
#  'im': 123,
#  'bringing': 23,
#  'monster': 4,
#  'load': 4,
#  'candy': 31,
#  'hope': 169,
#  'get': 512,
#  'squiched': 1,
#  'apple': 44,
#  'software': 8,
#  'retail': 5,
#  'chiefs': 10,
#  'overhaul': 6,
#  'san': 51,
#  'francisco': 7,
#  'inc': 9,
#  'ceo': 30,
#  'tim': 22,
#  'cook': 26,
#  'monday': 338,
#  'replaced': 4,
#  'heads': 11,
#  'x49zeosg': 1,
#  'oluoch': 1,
#  'victor': 12,
#  'otti': 1,
#  'kunjand': 1,
#  'watched': 70,
#  "sridevi's": 1,
#  'comeback': 6,
#  'u': 203,
#  'remember': 72,
#  '90s': 4,
#  'sun': 217,
#  'mornings': 3,
#  'nta': 8,
#  'one': 411,
#  'best': 214,
#  '8th': 65,
#  'graders': 1,
#  'kory': 1,
#  'excited': 125,
#  'touchdown': 4,
#  'today': 512,
#  'cruz': 13,
#  'lol': 183,
#  'tqorfrxb': 1,
#  'livewire': 1,
#  'nadal': 13,
#  'confirmed': 24,
#  'mexican': 10,
#  'open': 102,
#  'rafael': 5,
#  'set': 91,
#  'play': 217,
#  'zguxpcnc': 1,
#  'livewireathletics': 1,
#  'msshelahy': 1,
#  'didnt': 9,
#  'pop': 16,
#  'yep': 9,
#  'next': 220,
#  'wednesday': 179,
#  'come': 312,
#  'shes': 3,
#  'great': 184,
#  'ill': 31,
#  'tell': 59,
#  'asked': 31,
#  'alyoup005': 1,
#  'addicted2haley': 1,
#  'hmmmm': 4,
#  'november': 185,
#  'odd': 6,
#  'release': 32,
#  'date': 46,
#  'true': 63,
#  'becomes': 5,
#  'big': 211,
#  'enough': 37,
#  'maybe': 49,
#  'could': 83,
#  'sing': 16,
#  'grammys': 22,
#  'iran': 13,
#  'us': 235,
#  'delisting': 1,
#  'mko': 1,
#  'global': 8,
#  'terrorists': 1,
#  'list': 33,
#  'line': 58,
#  'campaign': 13,
#  'oct': 96,
#  '30': 116,
#  'irna': 1,
#  '--': 29,
#  'secretary': 3,
#  '9wwvxebf': 1,
#  'jackstirling': 1,
#  'serge': 2,
#  'amazing': 62,
#  'hes': 5,
#  'actually': 39,
#  'god': 53,
#  'lanky': 1,
#  'sex': 10,
#  'saw': 80,
#  'kasabian': 9,
#  'noel': 23,
#  'together': 29,
#  'august': 92,
#  'hatersgonnhate': 1,
#  'hamlikehussain': 1,
#  'ramythe3lite': 1,
#  'larry': 9,
#  'bird': 11,
#  'ranked': 8,
#  '4th': 199,
#  'all-time': 2,
#  'including': 18,
#  'lebron': 7,
#  'kobe': 4,
#  'sayin': 4,
#  'good': 412,
#  'morning': 239,
#  'becky': 9,
#  'thursday': 300,
#  'fantastic': 12,
#  'swedeng': 1,
#  'dj4jg': 1,
#  'grdina': 1,
#  'paverlayer': 1,
#  'fsbull': 1,
#  'revkahjc': 1,
#  'dickstrash': 1,
#  'borderfox116': 1,
#  'expect': 12,
#  'light-moderate': 1,
#  'rains': 5,
#  'e': 39,
#  'visayas': 1,
#  'cebu': 10,
#  'bohol': 2,
#  'samar': 1,
#  '&': 657,
#  'leyte': 1,
#  '30-70%': 1,
#  'chance': 59,
#  'tonight': 601,
#  'fair': 24,
#  'weather': 18,
#  'ticket': 32,
#  'left': 76,
#  '49ers': 4,
#  'game': 540,
#  'miss': 119,
#  'rematch': 5,
#  'nfc': 11,
#  'championship': 25,
#  'ny': 23,
#  'giants': 28,
#  'afc': 15,
#  'away': 47,
#  'fans': 75,
#  'stuff': 35,
#  "'she": 1,
#  'said': 140,
#  "no'": 2,
#  'chant': 1,
#  'bollocks': 1,
#  'ball': 33,
#  'turn': 27,
#  'back': 269,
#  'night': 854,
#  'consisted': 1,
#  'watching': 195,
#  'grey': 12,
#  'puppy': 4,
#  'parents': 10,
#  'throw': 17,
#  'rager': 1,
#  'whaa': 1,
#  'liamneesonisbosstho': 1,
#  'hard': 35,
#  'find': 77,
#  'tvguidemagazine': 1,
#  'days': 97,
#  'went': 85,
#  'stores': 11,
#  'castle': 16,
#  'cover': 22,
#  'issue': 20,
#  'none': 9,
#  'search': 9,
#  '1': 216,
#  'nlcs': 1,
#  "sf's": 2,
#  'gonna': 192,
#  'cuuuuhraaaaaaaazeeeee': 1,
#  'james': 49,
#  'hall': 44,
#  'live': 204,
#  'indianapolis': 10,
#  'dec': 34,
#  'christ': 3,
#  'church': 41,
#  'apostolic': 1,
#  "'": 37,
#  'tixs': 1,
#  '10': 158,
#  'adv': 4,
#  '15': 67,
#  'door': 12,
#  'trevorjavier': 1,
#  'heat': 73,
#  'cost': 10,
#  'alot': 9,
#  'plus': 28,
#  'would': 192,
#  'rather': 12,
#  'see': 605,
#  'austin': 25,
#  'rivers': 22,
#  'never': 82,
#  'start': 117,
#  'working': 38,
#  'dreams': 10,
#  'goals': 10,
#  'comes': 60,
#  'means': 25,
#  'anything': 30,
#  'act': 34,
#  'getafterit': 1,
#  'theffaddict': 1,
#  'vick': 6,
#  'flacco': 10,
#  'needed': 16,
#  'upgrade': 6,
#  'benched': 1,
#  'jennings': 4,
#  'soon': 61,
#  'thought': 53,
#  'win': 174,
#  'lisahochstein': 1,
#  'key': 3,
#  'largo': 1,
#  'fl': 13,
#  'yay': 21,
#  'ur': 28,
#  'neighbor': 4,
#  'lisa': 2,
#  'sip': 1,
#  'n': 80,
#  'hop': 11,
#  'always': 55,
#  'rhom': 1,
#  "thur's": 1,
#  'looks': 82,
#  'andy': 32,
#  'android': 13,
#  'little': 73,
#  'much': 96,
#  'fun': 76,
#  'yesterday': 82,
#  '7zdefzec': 1,
#  'apgphoto': 1,
#  'oooh': 4,
#  'nice': 54,
#  'tis': 1,
#  'tempting': 1,
#  'lakes': 2,
#  'nikon': 12,
#  'black': 120,
#  'friday': 531,
#  'huge': 20,
#  'saving': 3,
#  'aerial': 1,
#  'view': 9,
#  'city': 103,
#  'paris': 25,
#  'las': 18,
#  'vegas': 40,
#  'strip': 6,
#  'dctgesed': 1,
#  'yes': 69,
#  'know': 248,
#  'indio': 1,
#  'vs': 194,
#  'cv': 1,
#  'bell': 24,
#  'melmurmel': 1,
#  'pbandjenelley': 1,
#  'vl': 1,
#  'delp': 1,
#  'ham': 17,
#  'jenelle': 9,
#  'lies': 7,
#  '1st': 517,
#  'alone': 20,
#  '&the': 1,
#  'hosp': 1,
#  'saying': 32,
#  'weird': 19,
#  "keiffer's": 1,
#  'mybeautyisbrown': 1,
#  'lmfao': 21,
#  'ass': 41,
#  'nerves': 2,
#  'class': 61,
#  'tantrak': 1,
#  'hong': 11,
#  'kong': 10,
#  'time': 523,
#  'mama': 8,
#  'nov': 155,
#  '20th': 26,
#  'mr': 31,
#  'president': 46,
#  'forever': 13,
#  'chain': 4,
#  'dream': 33,
#  'high': 44,
#  '2': 365,
#  'sucks': 13,
#  'compared': 7,
#  'mohamed': 19,
#  'morsi': 18,
#  "egypt's": 12,
#  'muslim': 2,
#  'brotherhood': 1,
#  'instructed': 1,
#  'supreme': 2,
#  'council': 4,
#  'armed': 2,
#  'forces': 2,
#  'nnbeuvst': 1,
#  "c'mon": 59,
#  'avila': 1,
#  'got': 270,
#  'tagged': 1,
#  'guy': 62,
#  'kid': 24,
#  'bill': 38,
#  'murray': 41,
#  'researching': 1,
#  'royal': 27,
#  'tenenbaums': 1,
#  'tigers': 20,
#  'thehuwdavies': 1,
#  'think': 251,
#  'boro': 12,
#  'beat': 63,
#  'swansea': 5,
#  'sure': 116,
#  'december': 78,
#  'january': 77,
#  'implode': 2,
#  'first': 225,
#  'grammy': 23,
#  'awards': 59,
#  'held': 17,
#  '4': 192,
#  '1959': 1,
#  'domenico': 1,
#  'modugno': 1,
#  'frank': 14,
#  'sinatra': 1,
#  'peggy': 1,
#  'lee': 15,
#  'record': 40,
#  'year': 134,
#  'volare': 10,
#  'birthday': 150,
#  'vow': 20,
#  '3rd': 235,
#  'anniversary': 43,
#  'jennettemchevan': 1,
#  'studied': 1,
#  'friends': 48,
#  'omg': 37,
#  'jennette': 9,
#  'look': 95,
#  '<3': 55,
#  'life': 83,
#  'fragile': 2,
#  "we're": 71,
#  'guaranteed': 4,
#  'give': 81,
#  'jobs': 24,
#  'twitition': 1,
#  'mcfly': 2,
#  'argentina': 11,
#  'mar': 8,
#  'del': 8,
#  'plata': 1,
#  'dlxy0lcg': 1,
#  'astrochologist': 1,
#  'wondered': 1,
#  'aspects': 4,
#  'btwn': 2,
#  'moon': 25,
#  'faired': 1,
#  'rising': 19,
#  'also': 98,
#  'venus': 12,
#  'sag': 9,
#  'yea': 20,
#  'thank': 42,
#  'teachers': 1,
#  'call': 62,
#  'givng': 1,
#  'even': 125,
#  'might': 104,
#  'walmart': 6,
#  'cvs': 11,
#  'broncos': 4,
#  'peyton': 5,
#  'manning': 16,
#  'named': 18,
#  'offensive': 8,
#  'player': 35,
#  'month': 22,
#  '5th': 103,
#  'honor': 8,
#  'second': 36,
#  'tom': 40,
#  "brady's": 1,
#  '6': 121,
#  'tied': 6,
#  'w': 112,
#  'td': 11,
#  'toozany': 1,
#  'kendrick': 20,
#  'lamar': 18,
#  '6th': 90,
#  'tickets': 122,
#  'jackseymour11': 1,
#  'phone': 22,
#  'school': 112,
#  "andre's": 2,
#  'wigan': 7,
#  'warning': 5,
#  'coys': 3,
#  'official': 32,
#  'site': 12,
#  'currently': 9,
#  'occupy': 5,
#  '15th': 39,
#  'place': 106,
#  'premier': 25,
#  'league': 105,
#  '3mo7wiwd': 1,
#  'genesis8907': 1,
#  'tryst': 1,
#  'industry': 3,
#  'local': 11,
#  'party': 149,
#  'rained': 1,
#  'care': 33,
#  'someday': 5,
#  'shine': 9,
#  'right': 143,
#  'love': 293,
#  'mine': 13,
#  'valentine': 21,
#  'calebmac93': 1,
#  'strokemyego17': 1,
#  'rumble': 20,
#  'assemble': 2,
#  'crew': 12,
#  'gettin': 8,
#  'real': 105,
#  'haahaha': 1,
#  'juice005': 1,
#  'strange': 3,
#  'gallagher': 9,
#  'concert': 110,
#  'alldayb1tch': 1,
#  'professor': 4,
#  'passes': 3,
#  'small': 16,
#  'amount': 3,
#  'new': 384,
#  'york': 65,
#  'subways': 1,
#  'better': 140,
#  'clutch': 3,
#  'eli': 18,
#  'quarter': 41,
#  'homegrown': 1,
#  'talent': 13,
#  'missing': 24,
#  'signing': 21,
#  'throughout': 4,
#  'video': 78,
#  'scoreboard': 3,
#  '6dz2hqkd': 1,
#  'raleigh': 13,
#  'taylor': 45,
#  'swift': 13,
#  'coming': 162,
#  'ed': 9,
#  'sheeran': 2,
#  '29th': 18,
#  'perf': 1,
#  'news': 135,
#  "i've": 83,
#  'heard': 51,
#  'stage': 31,
#  'st': 69,
#  'paul': 48,
#  'plenty': 9,
#  'room': 50,
#  'row': 18,
#  'center': 89,
#  'pretty': 52,
#  'fired': 7,
#  "i'd": 38,
#  'pint': 2,
#  'jim': 32,
#  'white': 75,
#  'ssn': 1,
#  'bit': 96,
#  'lala': 2,
#  'cox': 2,
#  'ups': 2,
#  'downs': 2,
#  'cardiff': 8,
#  'leicester': 11,
#  'etc': 29,
#  'shout': 13,
#  'promo': 8,
#  'joeeewilliams': 1,
#  'amazon': 13,
#  '11am': 9,
#  'tuesday': 196,
#  'though': 78,
#  'sunday': 515,
#  'last': 353,
#  'sadat': 7,
#  'work': 143,
#  'enjoy': 41,
#  'tweeps': 7,
#  'yard': 7,
#  'couple': 16,
#  'hours': 35,
#  'playing': 110,
#  'browns': 7,
#  'hc': 3,
#  'k': 21,
#  'fri': 33,
#  'madden13': 1,
#  'xfacalac': 1,
#  'lost': 44,
#  'ravens': 43,
#  '21-28': 1,
#  'all-madden': 1,
#  'connectedcareers': 1,
#  'cfc': 8,
#  'juanmata10': 1,
#  'overall': 9,
#  'ea': 3,
#  'sports': 30,
#  'performance': 19,
#  'index': 2,
#  'score': 27,
#  '217': 1,
#  'matamagic': 1,
#  'rosanne': 4,
#  '89': 3,
#  'nooooooooo': 10,
#  "they've": 6,
#  'restocked': 1,
#  'overseas': 1,
#  'afford': 5,
#  'pain': 4,
#  'far': 52,
#  'deeper': 3,
#  'billy': 25,
#  'cundiff': 19,
#  'missed': 37,
#  'field': 30,
#  'goal': 38,
#  'gotta': 50,
#  'wake': 18,
#  'forget': 39,
#  'orioles': 1,
#  'stayhungry': 1,
#  'grandvincenzo': 1,
#  '16': 64,
#  'ready': 119,
#  'head': 53,
#  'movies': 35,
#  'breaking': 27,
#  'dawn': 10,
#  'part': 50,
#  'seeing': 47,
#  'iam': 3,
#  "faithreid's": 1,
#  'tweet': 46,
#  'need': 145,
#  'shall': 15,
#  'consist': 3,
#  'ferrell': 9,
#  'films': 12,
#  'fave': 4,
#  'people': 100,
#  'chinese': 25,
#  'food': 33,
#  'sweet': 19,
#  'yeah': 62,
#  'sitting': 13,
#  'around': 49,
#  'listening': 35,
#  'avril': 30,
#  'lavigne': 10,
#  'typical': 6,
#  'cardschatter': 1,
#  'azcardinalsftw': 1,
#  'closest': 4,
#  'source': 16,
#  'btw': 14,
#  'cards': 11,
#  'sign': 34,
#  'truth': 12,
#  'snarklife': 1,
#  'jbmclendon': 1,
#  'station': 8,
#  'air': 23,
#  'episodes': 12,
#  'cougar': 10,
#  'town': 46,
#  'tbsveryfunny': 1,
#  'jordan': 4,
#  'pennycan': 2,
#  'alex': 13,
#  'poythress': 1,
#  '11': 70,
#  'points': 28,
#  '7': 138,
#  'rebounds': 3,
#  'debut': 22,
#  'kentucky': 26,
#  'exhibition': 14,
#  'played': 54,
#  '28': 33,
#  'minutes': 32,
#  'heart': 21,
#  'attack': 8,
#  'jason': 47,
#  "wu's": 1,
#  'collection': 9,
#  'charlotte': 5,
#  'rampling': 1,
#  '2krw4ktn': 1,
#  'equipment': 2,
#  'correctly': 3,
#  'show': 246,
#  'pm': 59,
#  'cst': 10,
#  'contactee': 1,
#  'ray': 18,
#  '9lvkwcyj': 1,
#  'tcu': 3,
#  'jazz': 25,
#  'ensemble': 1,
#  'faculty': 1,
#  'combo': 4,
#  'i9asnset': 1,
#  'nationals': 1,
#  '9th': 49,
#  'inning': 5,
#  'redskins': 10,
#  'feel': 58,
#  'coulda': 1,
#  'swore': 1,
#  'shank': 2,
#  'mound': 1,
#  'wear': 21,
#  'shorts': 3,
#  'cold': 20,
#  'britain': 7,
#  "see's": 1,
#  "they're": 23,
#  "'oooh": 1,
#  "let's": 39,
#  'ppppolls': 1,
#  'mentioned': 7,
#  'releasing': 3,
#  'colorado': 10,
#  'nevada': 9,
#  'numbers': 5,
#  'polls': 9,
#  'abandoned': 2,
#  'capello': 21,
#  'russia': 32,
#  'match': 62,
#  'manager': 17,
#  'fabio': 13,
#  'intended': 4,
#  'efc5cfng': 2,
#  'jackals': 2,
#  'jimmy': 11,
#  'martin': 72,
#  'sneaks': 1,
#  'rebound': 3,
#  'past': 17,
#  'killeen': 1,
#  'elmira': 1,
#  '2-1': 9,
#  'lead': 35,
#  'bushee': 1,
#  'bellamy': 10,
#  'assists': 4,
#  '09': 3,
#  '2nd': 344,
#  'period': 11,
#  'kick-off': 3,
#  'weekend': 97,
#  'service': 22,
#  'ev': 1,
#  "'s": 9,
#  'bus': 16,
#  'trip': 38,
#  'boys': 54,
#  'girls': 59,
#  'club': 91,
#  '3-6': 2,
#  'nater0driguez': 1,
#  'alright': 14,
#  'job': 38,
#  'parker': 20,
#  'spurs': 40,
#  "y'all": 29,
#  'jan': 58,
#  'extra': 17,
#  'goin': 29,
#  'desperation': 9,
#  '13th': 29,
#  'well': 155,
#  'known': 13,
#  'mens': 2,
#  'sunnyclifford': 1,
#  'similar': 4,
#  'circumstance': 1,
#  'australia': 23,
#  '25': 41,
#  'many': 49,
#  'peoples': 1,
#  'invasion': 1,
#  'paul-and5homos': 1,
#  'louis': 19,
#  'fri-': 1,
#  'eleanor': 10,
#  'inspira-': 1,
#  'manwho-': 1,
#  'jxxtnlu6': 1,
#  'web': 6,
#  'reuters': 11,
#  'two': 86,
#  'fight': 40,
#  'cats': 8,
#  'dogs': 11,
#  'completely': 6,
#  'heels': 1,
#  'allie': 1,
#  'noah': 3,
#  'notebook': 8,
#  'paperchasinal': 1,
#  'damn': 52,
#  'tho': 35,
#  'niggas': 28,
#  'trynna': 3,
#  'early': 65,
#  'styles': 11,
#  '<33333': 1,
#  'bruno': 13,
#  'mars': 13,
#  'crazy': 28,
#  'long': 84,
#  'twin': 4,
#  'blog': 21,
#  'post': 38,
#  "mtv's": 1,
#  'teen': 14,
#  'mom': 44,
#  'returns': 7,
#  'intense': 5,
#  'third': 19,
#  'season': 211,
#  'chelsea': 18,
#  'kailyn': 1,
#  'leah': 1,
#  'mgmhsfvu': 1,
#  'business': 24,
#  "leader's": 1,
#  'award': 29,
#  'ceremony': 9,
#  'wef': 1,
#  'annual': 36,
#  'meeting': 26,
#  'davos': 12,
#  '2013': 25,
#  'yi4r8ufm': 1,
#  'elifyk1': 1,
#  'hi': 20,
#  'elif': 1,
#  'greetings': 4,
#  'usa': 20,
#  'midwest': 1,
#  'turkish': 1,
#  'republic': 13,
#  '8': 95,
#  'newglee': 1,
#  'hoping': 24,
#  'fit': 12,
#  'jeremy': 30,
#  'kyle': 32,
#  'itvfashion': 1,
#  'jordon': 1,
#  'atkins': 1,
#  'joe': 40,
#  'gone': 57,
#  'chill': 9,
#  'obma': 1,
#  'fails': 3,
#  '2unite': 1,
#  'divides': 1,
#  'color': 2,
#  'age': 12,
#  'wealth': 1,
#  "nevada's": 1,
#  'latino': 1,
#  'governor': 3,
#  'votes': 10,
#  'predicts': 1,
#  'gop': 16,
#  'pays': 4,
#  'moving': 28,
#  'tribute': 14,
#  'whitney': 6,
#  'houston': 29,
#  'given': 16,
#  'final': 79,
#  'sendoff': 2,
#  'halle': 3,
#  'calling': 11,
#  'voters': 7,
#  'florida': 42,
#  'ohio': 5,
#  'guys': 86,
#  'repeat': 10,
#  'lets': 28,
#  'tallied': 1,
#  'announcing': 6,
#  'winners': 10,
#  'communities': 1,
#  'tune': 19,
#  'xmaxmlcq': 1,
#  'radio': 34,
#  'rocks': 8,
#  'starting': 49,
#  'lounge': 16,
#  "fearnecotton's": 1,
#  'bullet': 8,
#  'drew': 19,
#  'peterson': 12,
#  'untouchable': 3,
#  'check': 105,
#  'photos': 17,
#  '6c': 2,
#  'lt9wukod': 1,
#  'hotspurrelated': 1,
#  '19': 29,
#  'old': 70,
#  'loan': 5,
#  'coventry': 1,
#  '79': 4,
#  'return': 34,
#  'bale': 12,
#  'ther': 2,
#  'halloween': 72,
#  'worst': 18,
#  'holiday': 18,
#  "valentine's": 32,
#  'pumped': 13,
#  'georgetown': 11,
#  "women's": 8,
#  'preview': 38,
#  '1k3pak3c': 1,
#  "men's": 7,
#  'n5ofat9v': 1,
#  'found': 50,
#  ...}
